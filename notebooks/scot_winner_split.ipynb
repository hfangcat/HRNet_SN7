# %% [markdown]
# # Evaluation Metrics: SCOT

# %%
from shapely.ops import cascaded_union
import matplotlib.pyplot as plt
import geopandas as gpd
import multiprocessing
import pandas as pd
import numpy as np
import skimage.io
import tqdm
import glob
import math
import gdal
import time
import sys
import os
import geopandas as gpd
from shapely import wkt

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
import matplotlib
# matplotlib.use('Agg') # non-interactive

import solaris as sol
from solaris.utils.core import _check_gdf_load
from solaris.raster.image import create_multiband_geotiff 

# import from data_postproc_funcs
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sn7_baseline_postproc_funcs import map_wrapper, multithread_polys, \
        calculate_iou, track_footprint_identifiers, \
        sn7_convert_geojsons_to_csv
import solaris.eval.scot as scot
# Out:
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
ground_truth = pd.read_csv('/local_storage/users/hfang/inference_winner_split/sn7_baseline_preds/csvs/ground_truth.csv')
aois = [z.split('mosaic_')[-1] for z in ground_truth['filename'].values]
ground_truth['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in ground_truth['filename'].values]
ground_truth['timestep'] = timesteps
ground_truth = ground_truth.drop('filename', 1)

# %%
ground_truth.head()
# Out:
#      id                                           geometry  \
# 0  1131  POLYGON ((1022.739556749351 1023.915693833842,...
# 1   896  POLYGON ((839.4174400521442 1023.860588716227,...
# 2   607  POLYGON ((977.5393254966475 1021.220368818729,...
# 3   539  POLYGON ((804.8580670831725 1021.935737615102,...
# 4   769  POLYGON ((817.6027463246137 1022.111423592898,...
#
#                             aoi timestep
# 0  L15-0387E-1276N_1549_3087_13  2018_01
# 1  L15-0387E-1276N_1549_3087_13  2018_01
# 2  L15-0387E-1276N_1549_3087_13  2018_01
# 3  L15-0387E-1276N_1549_3087_13  2018_01
# 4  L15-0387E-1276N_1549_3087_13  2018_01

# %%
ground_truth['geometry'] = ground_truth['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(ground_truth, geometry = 'geometry')
print(gdf)
# Out:
#           id                                           geometry  \
# 0       1131  POLYGON ((1022.740 1023.916, 1021.780 1025.799...
# 1        896  POLYGON ((839.417 1023.861, 832.526 1024.057, ...
# 2        607  POLYGON ((977.539 1021.220, 976.830 1024.765, ...
# 3        539  POLYGON ((804.858 1021.936, 801.562 1024.604, ...
# 4        769  POLYGON ((817.603 1022.111, 814.501 1024.105, ...
# ...      ...                                                ...
# 953426   199  POLYGON ((16.975 27.234, 23.288 27.566, 23.158...
# 953427   215  POLYGON ((264.036 7.059, 267.359 7.059, 267.35...
# 953428   225  POLYGON ((269.021 3.875, 273.175 3.875, 273.17...
# 953429   648  POLYGON ((267.221 3.459, 267.221 1.659, 269.15...
# 953430   625  POLYGON ((268.467 0.829, 268.467 -0.833, 271.7...
#
#                                  aoi timestep
# 0       L15-0387E-1276N_1549_3087_13  2018_01
# 1       L15-0387E-1276N_1549_3087_13  2018_01
# 2       L15-0387E-1276N_1549_3087_13  2018_01
# 3       L15-0387E-1276N_1549_3087_13  2018_01
# 4       L15-0387E-1276N_1549_3087_13  2018_01
# ...                              ...      ...
# 953426  L15-1848E-0793N_7394_5018_13  2020_01
# 953427  L15-1848E-0793N_7394_5018_13  2020_01
# 953428  L15-1848E-0793N_7394_5018_13  2020_01
# 953429  L15-1848E-0793N_7394_5018_13  2020_01
# 953430  L15-1848E-0793N_7394_5018_13  2020_01
#
# [953431 rows x 4 columns]

# %%
pred = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7/submission_hrnet.csv')
aois = [z.split('mosaic_')[-1] for z in pred['filename'].values]
pred['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in pred['filename'].values]
pred['timestep'] = timesteps
pred = pred.drop('filename', 1)

# %%
pred.head()
# Out:
#    id                                           geometry  \
# 0   0  POLYGON (( 2.7 37,2.7 37.3,2 37.7,2 39,1.7 39,...
# 1   0  POLYGON (( 2.7 37,2.7 37.3,2 37.7,2 39,1.7 39,...
# 2   0  POLYGON (( 2.7 37,2.7 37.3,2 37.7,2 39,1.7 39,...
# 3   0  POLYGON (( 2.7 37,2.7 37.3,2 37.7,2 39,1.7 39,...
# 4   0  POLYGON (( 2.7 37,2.7 37.3,2 37.7,2 39,1.7 39,...
#
#                             aoi timestep
# 0  L15-0632E-0892N_2528_4620_13  2018_01
# 1  L15-0632E-0892N_2528_4620_13  2018_02
# 2  L15-0632E-0892N_2528_4620_13  2018_03
# 3  L15-0632E-0892N_2528_4620_13  2018_04
# 4  L15-0632E-0892N_2528_4620_13  2018_05

# %%
pred['geometry'] = pred['geometry'].apply(wkt.loads)
pdf = gpd.GeoDataFrame(pred, geometry = 'geometry')
print(pdf)
# Out:
#           id                                           geometry  \
# 0          0  POLYGON ((2.700 37.000, 2.700 37.300, 2.000 37...
# 1          0  POLYGON ((2.700 37.000, 2.700 37.300, 2.000 37...
# 2          0  POLYGON ((2.700 37.000, 2.700 37.300, 2.000 37...
# 3          0  POLYGON ((2.700 37.000, 2.700 37.300, 2.000 37...
# 4          0  POLYGON ((2.700 37.000, 2.700 37.300, 2.000 37...
# ...      ...                                                ...
# 485743  2105  POLYGON ((941.000 1022.300, 941.000 1022.700, ...
# 485744  2105  POLYGON ((941.000 1022.300, 941.000 1022.700, ...
# 485745  2105  POLYGON ((941.000 1022.300, 941.000 1022.700, ...
# 485746  2105  POLYGON ((941.000 1022.300, 941.000 1022.700, ...
# 485747  2105  POLYGON ((941.000 1022.300, 941.000 1022.700, ...
#
#                                  aoi timestep
# 0       L15-0632E-0892N_2528_4620_13  2018_01
# 1       L15-0632E-0892N_2528_4620_13  2018_02
# 2       L15-0632E-0892N_2528_4620_13  2018_03
# 3       L15-0632E-0892N_2528_4620_13  2018_04
# 4       L15-0632E-0892N_2528_4620_13  2018_05
# ...                              ...      ...
# 485743  L15-1690E-1211N_6763_3346_13  2019_05
# 485744  L15-1690E-1211N_6763_3346_13  2019_06
# 485745  L15-1690E-1211N_6763_3346_13  2019_07
# 485746  L15-1690E-1211N_6763_3346_13  2019_08
# 485747  L15-1690E-1211N_6763_3346_13  2019_09
#
# [485748 rows x 4 columns]

# %%
scot.scot_multi_aoi(gdf, pdf, verbose=True)
# Out:
# 1 / 10: AOI L15-0387E-1276N_1549_3087_13
# Matching footprints
#    1: F1 = 0.2811
#    2: F1 = 0.2844
#    3: F1 = 0.2796
#    4: F1 = 0.2811
#    5: F1 = 0.2792
#    6: F1 = 0.2791
#    7: F1 = 0.2785
#    8: F1 = 0.2784
#    9: F1 = 0.2795
#   10: F1 = 0.2798
#   11: F1 = 0.2895
#   12: F1 = 0.2845
#   13: F1 = 0.2806
#   14: F1 = 0.2812
#   15: F1 = 0.2809
#   16: F1 = 0.2821
#   17: F1 = 0.2834
#   18: F1 = 0.2847
#   19: F1 = 0.2857
#   20: F1 = 0.2931
#   21: F1 = 0.2907
#   22: F1 = 0.2808
# Identifying mismatches
# Tracking:
#     Mismatches: 4
#       True Pos: 7389
#      False Pos: 7837
#      False Neg: 29696
#    Track Score: 0.2825
# Change Detection:
#       True Pos: 68
#      False Pos: 366
#      False Neg: 439
#   Change Score: 0.1445
# Combined Score: 0.2372
#
# 2 / 10: AOI L15-0566E-1185N_2265_3451_13
# Matching footprints
#    1: F1 = 0.3226
#    2: F1 = 0.2812
#    3: F1 = 0.2769
#    4: F1 = 0.2535
#    5: F1 = 0.3200
#    6: F1 = 0.3500
#    7: F1 = 0.3448
#    8: F1 = 0.2880
#    9: F1 = 0.2969
#   10: F1 = 0.3134
#   11: F1 = 0.2901
#   12: F1 = 0.3104
#   13: F1 = 0.3317
#   14: F1 = 0.3053
#   15: F1 = 0.2790
#   16: F1 = 0.2777
#   17: F1 = 0.3156
#   18: F1 = 0.2995
#   19: F1 = 0.3032
#   20: F1 = 0.3030
#   21: F1 = 0.3212
# Identifying mismatches
# Tracking:
#     Mismatches: 10
#       True Pos: 1173
#      False Pos: 1400
#      False Neg: 4016
#    Track Score: 0.3022
# Change Detection:
#       True Pos: 63
#      False Pos: 218
#      False Neg: 596
#   Change Score: 0.1340
# Combined Score: 0.2416
#
# 3 / 10: AOI L15-0632E-0892N_2528_4620_13
# Matching footprints
#    1: F1 = 0.2565
#    2: F1 = 0.2573
#    3: F1 = 0.2581
#    4: F1 = 0.2583
#    5: F1 = 0.2594
#    6: F1 = 0.2601
#    7: F1 = 0.2609
#    8: F1 = 0.2631
#    9: F1 = 0.2655
#   10: F1 = 0.2654
#   11: F1 = 0.2663
#   12: F1 = 0.2665
#   13: F1 = 0.2674
#   14: F1 = 0.2708
#   15: F1 = 0.2719
#   16: F1 = 0.2737
#   17: F1 = 0.2740
#   18: F1 = 0.2741
#   19: F1 = 0.2742
#   20: F1 = 0.2756
#   21: F1 = 0.2763
#   22: F1 = 0.2780
#   23: F1 = 0.2783
#   24: F1 = 0.2792
#   25: F1 = 0.2787
# Identifying mismatches
# Tracking:
#     Mismatches: 1
#       True Pos: 14253
#      False Pos: 28066
#      False Neg: 49587
#    Track Score: 0.2685
# Change Detection:
#       True Pos: 34
#      False Pos: 179
#      False Neg: 99
#   Change Score: 0.1965
# Combined Score: 0.2502
#
# 4 / 10: AOI L15-1015E-1062N_4061_3941_13
# Matching footprints
#    1: F1 = 0.4128
#    2: F1 = 0.4165
#    3: F1 = 0.4164
#    4: F1 = 0.4235
#    5: F1 = 0.4140
#    6: F1 = 0.4302
#    7: F1 = 0.4286
#    8: F1 = 0.4277
#    9: F1 = 0.4221
#   10: F1 = 0.4275
#   11: F1 = 0.4279
#   12: F1 = 0.4268
#   13: F1 = 0.4243
#   14: F1 = 0.4243
#   15: F1 = 0.4330
#   16: F1 = 0.4318
#   17: F1 = 0.4301
#   18: F1 = 0.4292
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 22056
#      False Pos: 24889
#      False Neg: 34774
#    Track Score: 0.4251
# Change Detection:
#       True Pos: 137
#      False Pos: 855
#      False Neg: 541
#   Change Score: 0.1641
# Combined Score: 0.3225
#
# 5 / 10: AOI L15-1200E-0847N_4802_4803_13
# Matching footprints
#    1: F1 = 0.2203
#    2: F1 = 0.2206
#    3: F1 = 0.2208
#    4: F1 = 0.2385
#    5: F1 = 0.2211
#    6: F1 = 0.2210
#    7: F1 = 0.2216
#    8: F1 = 0.2222
#    9: F1 = 0.2228
#   10: F1 = 0.2229
#   11: F1 = 0.2230
#   12: F1 = 0.2236
#   13: F1 = 0.2240
#   14: F1 = 0.2241
#   15: F1 = 0.2244
#   16: F1 = 0.2244
#   17: F1 = 0.2247
#   18: F1 = 0.2248
#   19: F1 = 0.2251
#   20: F1 = 0.2258
#   21: F1 = 0.2261
#   22: F1 = 0.2267
#   23: F1 = 0.2271
#   24: F1 = 0.2276
# Identifying mismatches
# Tracking:
#     Mismatches: 0
#       True Pos: 41634
#      False Pos: 63363
#      False Neg: 224680
#    Track Score: 0.2243
# Change Detection:
#       True Pos: 25
#      False Pos: 135
#      False Neg: 165
#   Change Score: 0.1429
# Combined Score: 0.2013
#
# 6 / 10: AOI L15-1276E-1107N_5105_3761_13
# Matching footprints
#    1: F1 = 0.4570
#    2: F1 = 0.4555
#    3: F1 = 0.4574
#    4: F1 = 0.4582
#    5: F1 = 0.4573
#    6: F1 = 0.4570
#    7: F1 = 0.4580
#    8: F1 = 0.4617
#    9: F1 = 0.4642
#   10: F1 = 0.4681
#   11: F1 = 0.4696
#   12: F1 = 0.4688
#   13: F1 = 0.4679
#   14: F1 = 0.4697
#   15: F1 = 0.4693
#   16: F1 = 0.4727
#   17: F1 = 0.4738
#   18: F1 = 0.4750
#   19: F1 = 0.4747
#   20: F1 = 0.4786
#   21: F1 = 0.4774
#   22: F1 = 0.4789
#   23: F1 = 0.4785
#   24: F1 = 0.4743
#   25: F1 = 0.4705
# Identifying mismatches
# Tracking:
#     Mismatches: 2
#       True Pos: 28105
#      False Pos: 18773
#      False Neg: 45045
#    Track Score: 0.4683
# Change Detection:
#       True Pos: 78
#      False Pos: 637
#      False Neg: 639
#   Change Score: 0.1089
# Combined Score: 0.2822
#
# 7 / 10: AOI L15-1438E-1134N_5753_3655_13
# Matching footprints
#    1: F1 = 0.3660
#    2: F1 = 0.3676
#    3: F1 = 0.3695
#    4: F1 = 0.3698
#    5: F1 = 0.3705
#    6: F1 = 0.3440
#    7: F1 = 0.3754
#    8: F1 = 0.3714
#    9: F1 = 0.3723
#   10: F1 = 0.3726
#   11: F1 = 0.3730
#   12: F1 = 0.3730
#   13: F1 = 0.3731
#   14: F1 = 0.3730
#   15: F1 = 0.3729
#   16: F1 = 0.3732
#   17: F1 = 0.3696
#   18: F1 = 0.3533
#   19: F1 = 0.3735
#   20: F1 = 0.3736
#   21: F1 = 0.3734
#   22: F1 = 0.3732
# Identifying mismatches
# Tracking:
#     Mismatches: 15
#       True Pos: 82657
#      False Pos: 55670
#      False Neg: 225183
#    Track Score: 0.3705
# Change Detection:
#       True Pos: 1
#      False Pos: 304
#      False Neg: 317
#   Change Score: 0.0032
# Combined Score: 0.0155
#
# 8 / 10: AOI L15-1615E-1206N_6460_3366_13
# Matching footprints
#    1: F1 = 0.3787
#    2: F1 = 0.3795
#    3: F1 = 0.3803
#    4: F1 = 0.3969
#    5: F1 = 0.3802
#    6: F1 = 0.3808
#    7: F1 = 0.3830
#    8: F1 = 0.3927
#    9: F1 = 0.3931
#   10: F1 = 0.4019
#   11: F1 = 0.4036
#   12: F1 = 0.4042
#   13: F1 = 0.4040
#   14: F1 = 0.4045
#   15: F1 = 0.4029
#   16: F1 = 0.3829
#   17: F1 = 0.4032
#   18: F1 = 0.4044
#   19: F1 = 0.4042
#   20: F1 = 0.4044
#   21: F1 = 0.4029
#   22: F1 = 0.4071
#   23: F1 = 0.4023
#   24: F1 = 0.3993
#   25: F1 = 0.4024
#   26: F1 = 0.4007
# Identifying mismatches
# Tracking:
#     Mismatches: 3
#       True Pos: 26772
#      False Pos: 25552
#      False Neg: 56165
#    Track Score: 0.3959
# Change Detection:
#       True Pos: 17
#      False Pos: 216
#      False Neg: 221
#   Change Score: 0.0722
# Combined Score: 0.2087
#
# 9 / 10: AOI L15-1690E-1211N_6763_3346_13
# Matching footprints
#    1: F1 = 0.5419
#    2: F1 = 0.5418
#    3: F1 = 0.5450
#    4: F1 = 0.5462
#    5: F1 = 0.5453
#    6: F1 = 0.5455
#    7: F1 = 0.5468
#    8: F1 = 0.5455
#    9: F1 = 0.5425
#   10: F1 = 0.5430
#   11: F1 = 0.5428
#   12: F1 = 0.5453
#   13: F1 = 0.5482
#   14: F1 = 0.5515
#   15: F1 = 0.5772
#   16: F1 = 0.4819
#   17: F1 = 0.5435
#   18: F1 = 0.5467
#   19: F1 = 0.5447
#   20: F1 = 0.5460
#   21: F1 = 0.5408
#   22: F1 = 0.5376
#   23: F1 = 0.5372
#   24: F1 = 0.5307
# Identifying mismatches
# Tracking:
#     Mismatches: 12
#       True Pos: 21212
#      False Pos: 9266
#      False Neg: 26423
#    Track Score: 0.5431
# Change Detection:
#       True Pos: 42
#      False Pos: 172
#      False Neg: 462
#   Change Score: 0.1170
# Combined Score: 0.3142
#
# 10 / 10: AOI L15-1848E-0793N_7394_5018_13
# Matching footprints
#    1: F1 = 0.3671
#    2: F1 = 0.3578
#    3: F1 = 0.2770
#    4: F1 = 0.2752
#    5: F1 = 0.2038
#    6: F1 = 0.2705
#    7: F1 = 0.2711
#    8: F1 = 0.2646
#    9: F1 = 0.7381
#   10: F1 = 0.7797
#   11: F1 = 0.2059
#   12: F1 = 0.2176
#   13: F1 = 0.2684
#   14: F1 = 0.2733
# Identifying mismatches
# Tracking:
#     Mismatches: 2
#       True Pos: 2509
#      False Pos: 3172
#      False Neg: 10102
#    Track Score: 0.2743
# Change Detection:
#       True Pos: 68
#      False Pos: 256
#      False Neg: 815
#   Change Score: 0.1127
# Combined Score: 0.2132
# Overall score: 0.228655
# (0.22865491421756196,
#  {'L15-0387E-1276N_1549_3087_13': [4,
#    7389,
#    7837,
#    29696,
#    0.2825027240924471,
#    68,
#    366,
#    439,
#    0.14452709883103082,
#    0.23721108293734183],
#   'L15-0566E-1185N_2265_3451_13': [10,
#    1173,
#    1400,
#    4016,
#    0.3022416902860088,
#    63,
#    218,
#    596,
#    0.13404255319148936,
#    0.2416070650915896],
#   'L15-0632E-0892N_2528_4620_13': [1,
#    14253,
#    28066,
#    49587,
#    0.26852174568336173,
#    34,
#    179,
#    99,
#    0.19653179190751446,
#    0.2501925483405013],
#   'L15-1015E-1062N_4061_3941_13': [6,
#    22056,
#    24889,
#    34774,
#    0.42507347627077813,
#    137,
#    855,
#    541,
#    0.16407185628742516,
#    0.32247603098411115],
#   'L15-1200E-0847N_4802_4803_13': [0,
#    41634,
#    63363,
#    224680,
#    0.22425406195884312,
#    25,
#    135,
#    165,
#    0.14285714285714285,
#    0.20131327002301608],
#   'L15-1276E-1107N_5105_3761_13': [2,
#    28105,
#    18773,
#    45045,
#    0.4683073949411804,
#    78,
#    637,
#    639,
#    0.10893854748603352,
#    0.2821529430892266],
#   'L15-1438E-1134N_5753_3655_13': [15,
#    82657,
#    55670,
#    225183,
#    0.37052045534519584,
#    1,
#    304,
#    317,
#    0.0032102728731942215,
#    0.015513707315838093],
#   'L15-1615E-1206N_6460_3366_13': [3,
#    26772,
#    25552,
#    56165,
#    0.3958568988843791,
#    17,
#    216,
#    221,
#    0.07218683651804671,
#    0.2087020162000352],
#   'L15-1690E-1211N_6763_3346_13': [12,
#    21212,
#    9266,
#    26423,
#    0.5431106217915072,
#    42,
#    172,
#    462,
#    0.116991643454039,
#    0.3142163847466953],
#   'L15-1848E-0793N_7394_5018_13': [2,
#    2509,
#    3172,
#    10102,
#    0.27432757489612947,
#    68,
#    256,
#    815,
#    0.11267605633802817,
#    0.21316409344726442]})
