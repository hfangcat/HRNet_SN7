# %% [markdown]
# # Evaluation Metrics: SCOT

# %%
from shapely.ops import cascaded_union
import matplotlib.pyplot as plt
import geopandas as gpd
import multiprocessing
import pandas as pd
import numpy as np
import skimage.io
import tqdm
import glob
import math
import gdal
import time
import sys
import os
import geopandas as gpd
from shapely import wkt

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
import matplotlib
# matplotlib.use('Agg') # non-interactive

import solaris as sol
from solaris.utils.core import _check_gdf_load
from solaris.raster.image import create_multiband_geotiff 

# import from data_postproc_funcs
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sn7_baseline_postproc_funcs import map_wrapper, multithread_polys, \
        calculate_iou, track_footprint_identifiers, \
        sn7_convert_geojsons_to_csv
import solaris.eval.scot as scot
# Out:
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
ground_truth = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7_csv/ground_truth.csv')
aois = [z.split('mosaic_')[-1] for z in ground_truth['filename'].values]
ground_truth['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in ground_truth['filename'].values]
ground_truth['timestep'] = timesteps
ground_truth = ground_truth.drop('filename', 1)

# %%
ground_truth.head()
# Out:
#      id                                           geometry  \
# 0  1131  POLYGON ((1022.739556749351 1023.915693833842,...
# 1   896  POLYGON ((839.4174400521442 1023.860588716227,...
# 2   607  POLYGON ((977.5393254966475 1021.220368818729,...
# 3   539  POLYGON ((804.8580670831725 1021.935737615102,...
# 4   769  POLYGON ((817.6027463246137 1022.111423592898,...
#
#                             aoi timestep
# 0  L15-0387E-1276N_1549_3087_13  2018_01
# 1  L15-0387E-1276N_1549_3087_13  2018_01
# 2  L15-0387E-1276N_1549_3087_13  2018_01
# 3  L15-0387E-1276N_1549_3087_13  2018_01
# 4  L15-0387E-1276N_1549_3087_13  2018_01

# %%
ground_truth['geometry'] = ground_truth['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(ground_truth, geometry = 'geometry')
print(gdf)
# Out:
#           id                                           geometry  \
# 0       1131  POLYGON ((1022.740 1023.916, 1021.780 1025.799...
# 1        896  POLYGON ((839.417 1023.861, 832.526 1024.057, ...
# 2        607  POLYGON ((977.539 1021.220, 976.830 1024.765, ...
# 3        539  POLYGON ((804.858 1021.936, 801.562 1024.604, ...
# 4        769  POLYGON ((817.603 1022.111, 814.501 1024.105, ...
# ...      ...                                                ...
# 953426   199  POLYGON ((16.975 27.234, 23.288 27.566, 23.158...
# 953427   215  POLYGON ((264.036 7.059, 267.359 7.059, 267.35...
# 953428   225  POLYGON ((269.021 3.875, 273.175 3.875, 273.17...
# 953429   648  POLYGON ((267.221 3.459, 267.221 1.659, 269.15...
# 953430   625  POLYGON ((268.467 0.829, 268.467 -0.833, 271.7...
#
#                                  aoi timestep
# 0       L15-0387E-1276N_1549_3087_13  2018_01
# 1       L15-0387E-1276N_1549_3087_13  2018_01
# 2       L15-0387E-1276N_1549_3087_13  2018_01
# 3       L15-0387E-1276N_1549_3087_13  2018_01
# 4       L15-0387E-1276N_1549_3087_13  2018_01
# ...                              ...      ...
# 953426  L15-1848E-0793N_7394_5018_13  2020_01
# 953427  L15-1848E-0793N_7394_5018_13  2020_01
# 953428  L15-1848E-0793N_7394_5018_13  2020_01
# 953429  L15-1848E-0793N_7394_5018_13  2020_01
# 953430  L15-1848E-0793N_7394_5018_13  2020_01
#
# [953431 rows x 4 columns]

# %%
pred = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7_csv/submission_hrnet_finetune5.csv')
aois = [z.split('mosaic_')[-1] for z in pred['filename'].values]
pred['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in pred['filename'].values]
pred['timestep'] = timesteps
pred = pred.drop('filename', 1)

# %%
pred.head()
# Out:
#    id                                           geometry  \
# 0   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 1   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 2   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 3   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 4   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
#
#                             aoi timestep
# 0  L15-0632E-0892N_2528_4620_13  2018_01
# 1  L15-0632E-0892N_2528_4620_13  2018_02
# 2  L15-0632E-0892N_2528_4620_13  2018_03
# 3  L15-0632E-0892N_2528_4620_13  2018_04
# 4  L15-0632E-0892N_2528_4620_13  2018_05

# %%
pred['geometry'] = pred['geometry'].apply(wkt.loads)
pdf = gpd.GeoDataFrame(pred, geometry = 'geometry')
print(pdf)
# Out:
#           id                                           geometry  \
# 0          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 1          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 2          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 3          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 4          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# ...      ...                                                ...
# 663197  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663198  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663199  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663200  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663201  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
#
#                                  aoi timestep
# 0       L15-0632E-0892N_2528_4620_13  2018_01
# 1       L15-0632E-0892N_2528_4620_13  2018_02
# 2       L15-0632E-0892N_2528_4620_13  2018_03
# 3       L15-0632E-0892N_2528_4620_13  2018_04
# 4       L15-0632E-0892N_2528_4620_13  2018_05
# ...                              ...      ...
# 663197  L15-1690E-1211N_6763_3346_13  2019_05
# 663198  L15-1690E-1211N_6763_3346_13  2019_06
# 663199  L15-1690E-1211N_6763_3346_13  2019_07
# 663200  L15-1690E-1211N_6763_3346_13  2019_08
# 663201  L15-1690E-1211N_6763_3346_13  2019_09
#
# [663202 rows x 4 columns]

# %%
scot.scot_multi_aoi(gdf, pdf, verbose=True)
# Out:
# 1 / 10: AOI L15-0387E-1276N_1549_3087_13
# Matching footprints
#    1: F1 = 0.4348
#    2: F1 = 0.4666
#    3: F1 = 0.4698
#    4: F1 = 0.4710
#    5: F1 = 0.4678
#    6: F1 = 0.4680
#    7: F1 = 0.4669
#    8: F1 = 0.4694
#    9: F1 = 0.4713
#   10: F1 = 0.4722
#   11: F1 = 0.4614
#   12: F1 = 0.4565
#   13: F1 = 0.4707
#   14: F1 = 0.4733
#   15: F1 = 0.4723
#   16: F1 = 0.4717
#   17: F1 = 0.4727
#   18: F1 = 0.4741
#   19: F1 = 0.4736
#   20: F1 = 0.4632
#   21: F1 = 0.4599
#   22: F1 = 0.4497
# Identifying mismatches
# Tracking:
#     Mismatches: 4
#       True Pos: 14002
#      False Pos: 8928
#      False Neg: 23083
#    Track Score: 0.4666
# Change Detection:
#       True Pos: 164
#      False Pos: 372
#      False Neg: 343
#   Change Score: 0.3145
# Combined Score: 0.4255
#
# 2 / 10: AOI L15-0566E-1185N_2265_3451_13
# Matching footprints
#    1: F1 = 0.3077
#    2: F1 = 0.2687
#    3: F1 = 0.2647
#    4: F1 = 0.2632
#    5: F1 = 0.3038
#    6: F1 = 0.3218
#    7: F1 = 0.3226
#    8: F1 = 0.3380
#    9: F1 = 0.3576
#   10: F1 = 0.5141
#   11: F1 = 0.5402
#   12: F1 = 0.5436
#   13: F1 = 0.6339
#   14: F1 = 0.6196
#   15: F1 = 0.5836
#   16: F1 = 0.5888
#   17: F1 = 0.6410
#   18: F1 = 0.6345
#   19: F1 = 0.6361
#   20: F1 = 0.6301
#   21: F1 = 0.6264
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 2691
#      False Pos: 1306
#      False Neg: 2498
#    Track Score: 0.5859
# Change Detection:
#       True Pos: 148
#      False Pos: 299
#      False Neg: 511
#   Change Score: 0.2676
# Combined Score: 0.4733
#
# 3 / 10: AOI L15-0632E-0892N_2528_4620_13
# Matching footprints
#    1: F1 = 0.4111
#    2: F1 = 0.4111
#    3: F1 = 0.4122
#    4: F1 = 0.4128
#    5: F1 = 0.4129
#    6: F1 = 0.4124
#    7: F1 = 0.4137
#    8: F1 = 0.4146
#    9: F1 = 0.4168
#   10: F1 = 0.4170
#   11: F1 = 0.4171
#   12: F1 = 0.4175
#   13: F1 = 0.4193
#   14: F1 = 0.4220
#   15: F1 = 0.4229
#   16: F1 = 0.4240
#   17: F1 = 0.4240
#   18: F1 = 0.4243
#   19: F1 = 0.4242
#   20: F1 = 0.4247
#   21: F1 = 0.4254
#   22: F1 = 0.4248
#   23: F1 = 0.4250
#   24: F1 = 0.4251
#   25: F1 = 0.4239
# Identifying mismatches
# Tracking:
#     Mismatches: 4
#       True Pos: 25550
#      False Pos: 32511
#      False Neg: 38290
#    Track Score: 0.4192
# Change Detection:
#       True Pos: 36
#      False Pos: 190
#      False Neg: 97
#   Change Score: 0.2006
# Combined Score: 0.3442
#
# 4 / 10: AOI L15-1015E-1062N_4061_3941_13
# Matching footprints
#    1: F1 = 0.6232
#    2: F1 = 0.6258
#    3: F1 = 0.6275
#    4: F1 = 0.6307
#    5: F1 = 0.6221
#    6: F1 = 0.6248
#    7: F1 = 0.6319
#    8: F1 = 0.6293
#    9: F1 = 0.6194
#   10: F1 = 0.6275
#   11: F1 = 0.6274
#   12: F1 = 0.6264
#   13: F1 = 0.6242
#   14: F1 = 0.6219
#   15: F1 = 0.6250
#   16: F1 = 0.6215
#   17: F1 = 0.6212
#   18: F1 = 0.6189
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 33813
#      False Pos: 17612
#      False Neg: 23017
#    Track Score: 0.6247
# Change Detection:
#       True Pos: 184
#      False Pos: 684
#      False Neg: 494
#   Change Score: 0.2380
# Combined Score: 0.4715
#
# 5 / 10: AOI L15-1200E-0847N_4802_4803_13
# Matching footprints
#    1: F1 = 0.4697
#    2: F1 = 0.4698
#    3: F1 = 0.4703
#    4: F1 = 0.4875
#    5: F1 = 0.4707
#    6: F1 = 0.4712
#    7: F1 = 0.4714
#    8: F1 = 0.4716
#    9: F1 = 0.4717
#   10: F1 = 0.4718
#   11: F1 = 0.4719
#   12: F1 = 0.4723
#   13: F1 = 0.4725
#   14: F1 = 0.4726
#   15: F1 = 0.4728
#   16: F1 = 0.4728
#   17: F1 = 0.4733
#   18: F1 = 0.4733
#   19: F1 = 0.4740
#   20: F1 = 0.4747
#   21: F1 = 0.4746
#   22: F1 = 0.4745
#   23: F1 = 0.4752
#   24: F1 = 0.4746
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 102581
#      False Pos: 64808
#      False Neg: 163733
#    Track Score: 0.4730
# Change Detection:
#       True Pos: 36
#      False Pos: 196
#      False Neg: 154
#   Change Score: 0.1706
# Combined Score: 0.3492
#
# 6 / 10: AOI L15-1276E-1107N_5105_3761_13
# Matching footprints
#    1: F1 = 0.5179
#    2: F1 = 0.5172
#    3: F1 = 0.5166
#    4: F1 = 0.5169
#    5: F1 = 0.5170
#    6: F1 = 0.5168
#    7: F1 = 0.5176
#    8: F1 = 0.5147
#    9: F1 = 0.5153
#   10: F1 = 0.5189
#   11: F1 = 0.5197
#   12: F1 = 0.5181
#   13: F1 = 0.5164
#   14: F1 = 0.5177
#   15: F1 = 0.5152
#   16: F1 = 0.5146
#   17: F1 = 0.5147
#   18: F1 = 0.5149
#   19: F1 = 0.5147
#   20: F1 = 0.5178
#   21: F1 = 0.5174
#   22: F1 = 0.5186
#   23: F1 = 0.5187
#   24: F1 = 0.5181
#   25: F1 = 0.5154
# Identifying mismatches
# Tracking:
#     Mismatches: 3
#       True Pos: 31041
#      False Pos: 15940
#      False Neg: 42109
#    Track Score: 0.5168
# Change Detection:
#       True Pos: 71
#      False Pos: 552
#      False Neg: 646
#   Change Score: 0.1060
# Combined Score: 0.2911
#
# 7 / 10: AOI L15-1438E-1134N_5753_3655_13
# Matching footprints
#    1: F1 = 0.4765
#    2: F1 = 0.4777
#    3: F1 = 0.4793
#    4: F1 = 0.4791
#    5: F1 = 0.4793
#    6: F1 = 0.4548
#    7: F1 = 0.4836
#    8: F1 = 0.4800
#    9: F1 = 0.4809
#   10: F1 = 0.4810
#   11: F1 = 0.4814
#   12: F1 = 0.4813
#   13: F1 = 0.4811
#   14: F1 = 0.4811
#   15: F1 = 0.4806
#   16: F1 = 0.4808
#   17: F1 = 0.4776
#   18: F1 = 0.4610
#   19: F1 = 0.4803
#   20: F1 = 0.4803
#   21: F1 = 0.4801
#   22: F1 = 0.4800
# Identifying mismatches
# Tracking:
#     Mismatches: 23
#       True Pos: 119923
#      False Pos: 73177
#      False Neg: 187917
#    Track Score: 0.4788
# Change Detection:
#       True Pos: 2
#      False Pos: 423
#      False Neg: 316
#   Change Score: 0.0054
# Combined Score: 0.0258
#
# 8 / 10: AOI L15-1615E-1206N_6460_3366_13
# Matching footprints
#    1: F1 = 0.5819
#    2: F1 = 0.5829
#    3: F1 = 0.5819
#    4: F1 = 0.6114
#    5: F1 = 0.5842
#    6: F1 = 0.5859
#    7: F1 = 0.5871
#    8: F1 = 0.5992
#    9: F1 = 0.6009
#   10: F1 = 0.6125
#   11: F1 = 0.6144
#   12: F1 = 0.6157
#   13: F1 = 0.6151
#   14: F1 = 0.6056
#   15: F1 = 0.6145
#   16: F1 = 0.5837
#   17: F1 = 0.6142
#   18: F1 = 0.6157
#   19: F1 = 0.6153
#   20: F1 = 0.6162
#   21: F1 = 0.6153
#   22: F1 = 0.6137
#   23: F1 = 0.6138
#   24: F1 = 0.6166
#   25: F1 = 0.6115
#   26: F1 = 0.6016
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 46686
#      False Pos: 24950
#      False Neg: 36251
#    Track Score: 0.6041
# Change Detection:
#       True Pos: 32
#      False Pos: 281
#      False Neg: 206
#   Change Score: 0.1162
# Combined Score: 0.3283
#
# 9 / 10: AOI L15-1690E-1211N_6763_3346_13
# Matching footprints
#    1: F1 = 0.6127
#    2: F1 = 0.6119
#    3: F1 = 0.6118
#    4: F1 = 0.6130
#    5: F1 = 0.6142
#    6: F1 = 0.6138
#    7: F1 = 0.6151
#    8: F1 = 0.6156
#    9: F1 = 0.6128
#   10: F1 = 0.6136
#   11: F1 = 0.6131
#   12: F1 = 0.6143
#   13: F1 = 0.6116
#   14: F1 = 0.6069
#   15: F1 = 0.5936
#   16: F1 = 0.5772
#   17: F1 = 0.5972
#   18: F1 = 0.5977
#   19: F1 = 0.5974
#   20: F1 = 0.5947
#   21: F1 = 0.5865
#   22: F1 = 0.5854
#   23: F1 = 0.5847
#   24: F1 = 0.5773
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 26072
#      False Pos: 12738
#      False Neg: 21563
#    Track Score: 0.6032
# Change Detection:
#       True Pos: 41
#      False Pos: 189
#      False Neg: 463
#   Change Score: 0.1117
# Combined Score: 0.3209
#
# 10 / 10: AOI L15-1848E-0793N_7394_5018_13
# Matching footprints
#    1: F1 = 0.5212
#    2: F1 = 0.5271
#    3: F1 = 0.4700
#    4: F1 = 0.4724
#    5: F1 = 0.4465
#    6: F1 = 0.4739
#    7: F1 = 0.4737
#    8: F1 = 0.4722
#    9: F1 = 0.7500
#   10: F1 = 0.7719
#   11: F1 = 0.4243
#   12: F1 = 0.4292
#   13: F1 = 0.4635
#   14: F1 = 0.4631
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 5056
#      False Pos: 3817
#      False Neg: 7555
#    Track Score: 0.4707
# Change Detection:
#       True Pos: 157
#      False Pos: 348
#      False Neg: 726
#   Change Score: 0.2262
# Combined Score: 0.3870
# Overall score: 0.341670
# (0.34167040281301764,
#  {'L15-0387E-1276N_1549_3087_13': [4,
#    14002,
#    8928,
#    23083,
#    0.46661667916354244,
#    164,
#    372,
#    343,
#    0.3144774688398849,
#    0.42545135590099564],
#   'L15-0566E-1185N_2265_3451_13': [6,
#    2691,
#    1306,
#    2498,
#    0.5858915741345526,
#    148,
#    299,
#    511,
#    0.26763110307414106,
#    0.47331953311233027],
#   'L15-0632E-0892N_2528_4620_13': [4,
#    25550,
#    32511,
#    38290,
#    0.4191926235223665,
#    36,
#    190,
#    97,
#    0.20055710306406685,
#    0.3441567474964823],
#   'L15-1015E-1062N_4061_3941_13': [7,
#    33813,
#    17612,
#    23017,
#    0.6246917001524179,
#    184,
#    684,
#    494,
#    0.23803363518758086,
#    0.47150926462785175],
#   'L15-1200E-0847N_4802_4803_13': [6,
#    102581,
#    64808,
#    163733,
#    0.4730472235608239,
#    36,
#    196,
#    154,
#    0.17061611374407584,
#    0.3492369674859135],
#   'L15-1276E-1107N_5105_3761_13': [3,
#    31041,
#    15940,
#    42109,
#    0.5167858421223498,
#    71,
#    552,
#    646,
#    0.10597014925373134,
#    0.2910908189312404],
#   'L15-1438E-1134N_5753_3655_13': [23,
#    119923,
#    73177,
#    187917,
#    0.47879187128198986,
#    2,
#    423,
#    316,
#    0.005383580080753701,
#    0.025759338850438136],
#   'L15-1615E-1206N_6460_3366_13': [7,
#    46686,
#    24950,
#    36251,
#    0.604064099163502,
#    32,
#    281,
#    206,
#    0.1161524500907441,
#    0.32827378473820645],
#   'L15-1690E-1211N_6763_3346_13': [7,
#    26072,
#    12738,
#    21563,
#    0.6032043495864422,
#    41,
#    189,
#    463,
#    0.11171662125340599,
#    0.320873362256658],
#   'L15-1848E-0793N_7394_5018_13': [7,
#    5056,
#    3817,
#    7555,
#    0.4706758517966859,
#    157,
#    348,
#    726,
#    0.22622478386167147,
#    0.38703285473005916]})
