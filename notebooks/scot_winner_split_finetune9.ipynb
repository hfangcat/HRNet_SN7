# %% [markdown]
# # Evaluation Metrics: SCOT

# %%
from shapely.ops import cascaded_union
import matplotlib.pyplot as plt
import geopandas as gpd
import multiprocessing
import pandas as pd
import numpy as np
import skimage.io
import tqdm
import glob
import math
import gdal
import time
import sys
import os
import geopandas as gpd
from shapely import wkt

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
import matplotlib
# matplotlib.use('Agg') # non-interactive

import solaris as sol
from solaris.utils.core import _check_gdf_load
from solaris.raster.image import create_multiband_geotiff 

# import from data_postproc_funcs
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sn7_baseline_postproc_funcs import map_wrapper, multithread_polys, \
        calculate_iou, track_footprint_identifiers, \
        sn7_convert_geojsons_to_csv
import solaris.eval.scot as scot
# Out:
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
ground_truth = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7_csv/ground_truth.csv')
aois = [z.split('mosaic_')[-1] for z in ground_truth['filename'].values]
ground_truth['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in ground_truth['filename'].values]
ground_truth['timestep'] = timesteps
ground_truth = ground_truth.drop('filename', 1)

# %%
ground_truth.head()
# Out:
#      id                                           geometry  \
# 0  1131  POLYGON ((1022.739556749351 1023.915693833842,...
# 1   896  POLYGON ((839.4174400521442 1023.860588716227,...
# 2   607  POLYGON ((977.5393254966475 1021.220368818729,...
# 3   539  POLYGON ((804.8580670831725 1021.935737615102,...
# 4   769  POLYGON ((817.6027463246137 1022.111423592898,...
#
#                             aoi timestep
# 0  L15-0387E-1276N_1549_3087_13  2018_01
# 1  L15-0387E-1276N_1549_3087_13  2018_01
# 2  L15-0387E-1276N_1549_3087_13  2018_01
# 3  L15-0387E-1276N_1549_3087_13  2018_01
# 4  L15-0387E-1276N_1549_3087_13  2018_01

# %%
ground_truth['geometry'] = ground_truth['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(ground_truth, geometry = 'geometry')
print(gdf)
# Out:
#           id                                           geometry  \
# 0       1131  POLYGON ((1022.740 1023.916, 1021.780 1025.799...
# 1        896  POLYGON ((839.417 1023.861, 832.526 1024.057, ...
# 2        607  POLYGON ((977.539 1021.220, 976.830 1024.765, ...
# 3        539  POLYGON ((804.858 1021.936, 801.562 1024.604, ...
# 4        769  POLYGON ((817.603 1022.111, 814.501 1024.105, ...
# ...      ...                                                ...
# 953426   199  POLYGON ((16.975 27.234, 23.288 27.566, 23.158...
# 953427   215  POLYGON ((264.036 7.059, 267.359 7.059, 267.35...
# 953428   225  POLYGON ((269.021 3.875, 273.175 3.875, 273.17...
# 953429   648  POLYGON ((267.221 3.459, 267.221 1.659, 269.15...
# 953430   625  POLYGON ((268.467 0.829, 268.467 -0.833, 271.7...
#
#                                  aoi timestep
# 0       L15-0387E-1276N_1549_3087_13  2018_01
# 1       L15-0387E-1276N_1549_3087_13  2018_01
# 2       L15-0387E-1276N_1549_3087_13  2018_01
# 3       L15-0387E-1276N_1549_3087_13  2018_01
# 4       L15-0387E-1276N_1549_3087_13  2018_01
# ...                              ...      ...
# 953426  L15-1848E-0793N_7394_5018_13  2020_01
# 953427  L15-1848E-0793N_7394_5018_13  2020_01
# 953428  L15-1848E-0793N_7394_5018_13  2020_01
# 953429  L15-1848E-0793N_7394_5018_13  2020_01
# 953430  L15-1848E-0793N_7394_5018_13  2020_01
#
# [953431 rows x 4 columns]

# %%
pred = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7_csv/submission_hrnet_finetune9.csv')
aois = [z.split('mosaic_')[-1] for z in pred['filename'].values]
pred['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in pred['filename'].values]
pred['timestep'] = timesteps
pred = pred.drop('filename', 1)

# %%
pred.head()
# Out:
#    id                                           geometry  \
# 0   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 1   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 2   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 3   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 4   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
#
#                             aoi timestep
# 0  L15-0632E-0892N_2528_4620_13  2018_01
# 1  L15-0632E-0892N_2528_4620_13  2018_02
# 2  L15-0632E-0892N_2528_4620_13  2018_03
# 3  L15-0632E-0892N_2528_4620_13  2018_04
# 4  L15-0632E-0892N_2528_4620_13  2018_05

# %%
pred['geometry'] = pred['geometry'].apply(wkt.loads)
pdf = gpd.GeoDataFrame(pred, geometry = 'geometry')
print(pdf)
# Out:
#           id                                           geometry  \
# 0          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 1          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 2          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 3          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 4          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# ...      ...                                                ...
# 663163  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663164  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663165  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663166  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663167  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
#
#                                  aoi timestep
# 0       L15-0632E-0892N_2528_4620_13  2018_01
# 1       L15-0632E-0892N_2528_4620_13  2018_02
# 2       L15-0632E-0892N_2528_4620_13  2018_03
# 3       L15-0632E-0892N_2528_4620_13  2018_04
# 4       L15-0632E-0892N_2528_4620_13  2018_05
# ...                              ...      ...
# 663163  L15-1690E-1211N_6763_3346_13  2019_05
# 663164  L15-1690E-1211N_6763_3346_13  2019_06
# 663165  L15-1690E-1211N_6763_3346_13  2019_07
# 663166  L15-1690E-1211N_6763_3346_13  2019_08
# 663167  L15-1690E-1211N_6763_3346_13  2019_09
#
# [663168 rows x 4 columns]

# %%
scot.scot_multi_aoi(gdf, pdf, verbose=True)
# Out:
# 1 / 10: AOI L15-0387E-1276N_1549_3087_13
# Matching footprints
#    1: F1 = 0.4337
#    2: F1 = 0.4664
#    3: F1 = 0.4687
#    4: F1 = 0.4699
#    5: F1 = 0.4678
#    6: F1 = 0.4680
#    7: F1 = 0.4664
#    8: F1 = 0.4688
#    9: F1 = 0.4713
#   10: F1 = 0.4726
#   11: F1 = 0.4628
#   12: F1 = 0.4579
#   13: F1 = 0.4714
#   14: F1 = 0.4741
#   15: F1 = 0.4733
#   16: F1 = 0.4728
#   17: F1 = 0.4738
#   18: F1 = 0.4752
#   19: F1 = 0.4752
#   20: F1 = 0.4657
#   21: F1 = 0.4627
#   22: F1 = 0.4523
# Identifying mismatches
# Tracking:
#     Mismatches: 4
#       True Pos: 14012
#      False Pos: 8876
#      False Neg: 23073
#    Track Score: 0.4673
# Change Detection:
#       True Pos: 164
#      False Pos: 350
#      False Neg: 343
#   Change Score: 0.3213
# Combined Score: 0.4283
#
# 2 / 10: AOI L15-0566E-1185N_2265_3451_13
# Matching footprints
#    1: F1 = 0.3077
#    2: F1 = 0.2687
#    3: F1 = 0.2647
#    4: F1 = 0.2632
#    5: F1 = 0.3038
#    6: F1 = 0.3218
#    7: F1 = 0.3226
#    8: F1 = 0.3380
#    9: F1 = 0.3576
#   10: F1 = 0.5141
#   11: F1 = 0.5402
#   12: F1 = 0.5436
#   13: F1 = 0.6352
#   14: F1 = 0.6182
#   15: F1 = 0.5822
#   16: F1 = 0.5840
#   17: F1 = 0.6379
#   18: F1 = 0.6317
#   19: F1 = 0.6323
#   20: F1 = 0.6264
#   21: F1 = 0.6228
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 2674
#      False Pos: 1303
#      False Neg: 2515
#    Track Score: 0.5835
# Change Detection:
#       True Pos: 146
#      False Pos: 298
#      False Neg: 513
#   Change Score: 0.2647
# Combined Score: 0.4702
#
# 3 / 10: AOI L15-0632E-0892N_2528_4620_13
# Matching footprints
#    1: F1 = 0.4103
#    2: F1 = 0.4104
#    3: F1 = 0.4117
#    4: F1 = 0.4124
#    5: F1 = 0.4127
#    6: F1 = 0.4123
#    7: F1 = 0.4136
#    8: F1 = 0.4146
#    9: F1 = 0.4168
#   10: F1 = 0.4170
#   11: F1 = 0.4172
#   12: F1 = 0.4177
#   13: F1 = 0.4195
#   14: F1 = 0.4223
#   15: F1 = 0.4232
#   16: F1 = 0.4243
#   17: F1 = 0.4243
#   18: F1 = 0.4247
#   19: F1 = 0.4246
#   20: F1 = 0.4251
#   21: F1 = 0.4258
#   22: F1 = 0.4253
#   23: F1 = 0.4255
#   24: F1 = 0.4256
#   25: F1 = 0.4244
# Identifying mismatches
# Tracking:
#     Mismatches: 4
#       True Pos: 25551
#      False Pos: 32488
#      False Neg: 38289
#    Track Score: 0.4193
# Change Detection:
#       True Pos: 36
#      False Pos: 170
#      False Neg: 97
#   Change Score: 0.2124
# Combined Score: 0.3509
#
# 4 / 10: AOI L15-1015E-1062N_4061_3941_13
# Matching footprints
#    1: F1 = 0.6199
#    2: F1 = 0.6224
#    3: F1 = 0.6241
#    4: F1 = 0.6278
#    5: F1 = 0.6198
#    6: F1 = 0.6219
#    7: F1 = 0.6309
#    8: F1 = 0.6287
#    9: F1 = 0.6192
#   10: F1 = 0.6278
#   11: F1 = 0.6281
#   12: F1 = 0.6274
#   13: F1 = 0.6255
#   14: F1 = 0.6231
#   15: F1 = 0.6263
#   16: F1 = 0.6234
#   17: F1 = 0.6231
#   18: F1 = 0.6208
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 33798
#      False Pos: 17633
#      False Neg: 23032
#    Track Score: 0.6244
# Change Detection:
#       True Pos: 181
#      False Pos: 629
#      False Neg: 497
#   Change Score: 0.2433
# Combined Score: 0.4754
#
# 5 / 10: AOI L15-1200E-0847N_4802_4803_13
# Matching footprints
#    1: F1 = 0.4699
#    2: F1 = 0.4700
#    3: F1 = 0.4705
#    4: F1 = 0.4876
#    5: F1 = 0.4710
#    6: F1 = 0.4715
#    7: F1 = 0.4717
#    8: F1 = 0.4720
#    9: F1 = 0.4722
#   10: F1 = 0.4723
#   11: F1 = 0.4724
#   12: F1 = 0.4727
#   13: F1 = 0.4730
#   14: F1 = 0.4730
#   15: F1 = 0.4733
#   16: F1 = 0.4732
#   17: F1 = 0.4737
#   18: F1 = 0.4738
#   19: F1 = 0.4745
#   20: F1 = 0.4751
#   21: F1 = 0.4751
#   22: F1 = 0.4749
#   23: F1 = 0.4756
#   24: F1 = 0.4750
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 102684
#      False Pos: 64789
#      False Neg: 163630
#    Track Score: 0.4734
# Change Detection:
#       True Pos: 36
#      False Pos: 177
#      False Neg: 154
#   Change Score: 0.1787
# Combined Score: 0.3560
#
# 6 / 10: AOI L15-1276E-1107N_5105_3761_13
# Matching footprints
#    1: F1 = 0.5167
#    2: F1 = 0.5160
#    3: F1 = 0.5154
#    4: F1 = 0.5160
#    5: F1 = 0.5162
#    6: F1 = 0.5160
#    7: F1 = 0.5169
#    8: F1 = 0.5145
#    9: F1 = 0.5151
#   10: F1 = 0.5187
#   11: F1 = 0.5196
#   12: F1 = 0.5182
#   13: F1 = 0.5166
#   14: F1 = 0.5176
#   15: F1 = 0.5149
#   16: F1 = 0.5144
#   17: F1 = 0.5145
#   18: F1 = 0.5150
#   19: F1 = 0.5139
#   20: F1 = 0.5169
#   21: F1 = 0.5165
#   22: F1 = 0.5177
#   23: F1 = 0.5185
#   24: F1 = 0.5177
#   25: F1 = 0.5154
# Identifying mismatches
# Tracking:
#     Mismatches: 3
#       True Pos: 30982
#      False Pos: 15879
#      False Neg: 42168
#    Track Score: 0.5163
# Change Detection:
#       True Pos: 68
#      False Pos: 526
#      False Neg: 649
#   Change Score: 0.1037
# Combined Score: 0.2876
#
# 7 / 10: AOI L15-1438E-1134N_5753_3655_13
# Matching footprints
#    1: F1 = 0.4769
#    2: F1 = 0.4780
#    3: F1 = 0.4796
#    4: F1 = 0.4795
#    5: F1 = 0.4796
#    6: F1 = 0.4554
#    7: F1 = 0.4836
#    8: F1 = 0.4805
#    9: F1 = 0.4815
#   10: F1 = 0.4815
#   11: F1 = 0.4820
#   12: F1 = 0.4819
#   13: F1 = 0.4817
#   14: F1 = 0.4817
#   15: F1 = 0.4812
#   16: F1 = 0.4814
#   17: F1 = 0.4783
#   18: F1 = 0.4616
#   19: F1 = 0.4810
#   20: F1 = 0.4810
#   21: F1 = 0.4808
#   22: F1 = 0.4807
# Identifying mismatches
# Tracking:
#     Mismatches: 25
#       True Pos: 120074
#      False Pos: 73104
#      False Neg: 187766
#    Track Score: 0.4793
# Change Detection:
#       True Pos: 2
#      False Pos: 332
#      False Neg: 316
#   Change Score: 0.0061
# Combined Score: 0.0292
#
# 8 / 10: AOI L15-1615E-1206N_6460_3366_13
# Matching footprints
#    1: F1 = 0.5801
#    2: F1 = 0.5810
#    3: F1 = 0.5803
#    4: F1 = 0.6103
#    5: F1 = 0.5827
#    6: F1 = 0.5849
#    7: F1 = 0.5865
#    8: F1 = 0.5990
#    9: F1 = 0.6007
#   10: F1 = 0.6125
#   11: F1 = 0.6146
#   12: F1 = 0.6157
#   13: F1 = 0.6151
#   14: F1 = 0.6058
#   15: F1 = 0.6147
#   16: F1 = 0.5833
#   17: F1 = 0.6144
#   18: F1 = 0.6161
#   19: F1 = 0.6157
#   20: F1 = 0.6167
#   21: F1 = 0.6158
#   22: F1 = 0.6143
#   23: F1 = 0.6143
#   24: F1 = 0.6173
#   25: F1 = 0.6122
#   26: F1 = 0.6028
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 46675
#      False Pos: 24972
#      False Neg: 36262
#    Track Score: 0.6039
# Change Detection:
#       True Pos: 29
#      False Pos: 250
#      False Neg: 209
#   Change Score: 0.1122
# Combined Score: 0.3218
#
# 9 / 10: AOI L15-1690E-1211N_6763_3346_13
# Matching footprints
#    1: F1 = 0.6117
#    2: F1 = 0.6111
#    3: F1 = 0.6109
#    4: F1 = 0.6123
#    5: F1 = 0.6139
#    6: F1 = 0.6138
#    7: F1 = 0.6151
#    8: F1 = 0.6156
#    9: F1 = 0.6128
#   10: F1 = 0.6136
#   11: F1 = 0.6131
#   12: F1 = 0.6143
#   13: F1 = 0.6116
#   14: F1 = 0.6071
#   15: F1 = 0.5938
#   16: F1 = 0.5772
#   17: F1 = 0.5974
#   18: F1 = 0.5980
#   19: F1 = 0.5977
#   20: F1 = 0.5950
#   21: F1 = 0.5868
#   22: F1 = 0.5859
#   23: F1 = 0.5852
#   24: F1 = 0.5777
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 26074
#      False Pos: 12744
#      False Neg: 21561
#    Track Score: 0.6032
# Change Detection:
#       True Pos: 41
#      False Pos: 177
#      False Neg: 463
#   Change Score: 0.1136
# Combined Score: 0.3239
#
# 10 / 10: AOI L15-1848E-0793N_7394_5018_13
# Matching footprints
#    1: F1 = 0.5183
#    2: F1 = 0.5243
#    3: F1 = 0.4690
#    4: F1 = 0.4717
#    5: F1 = 0.4459
#    6: F1 = 0.4737
#    7: F1 = 0.4734
#    8: F1 = 0.4722
#    9: F1 = 0.7595
#   10: F1 = 0.7857
#   11: F1 = 0.4278
#   12: F1 = 0.4326
#   13: F1 = 0.4647
#   14: F1 = 0.4643
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 5054
#      False Pos: 3802
#      False Neg: 7557
#    Track Score: 0.4709
# Change Detection:
#       True Pos: 155
#      False Pos: 332
#      False Neg: 728
#   Change Score: 0.2263
# Combined Score: 0.3872
# Overall score: 0.343051
# (0.343051369608831,
#  {'L15-0387E-1276N_1549_3087_13': [4,
#    14012,
#    8876,
#    23073,
#    0.46727694129024727,
#    164,
#    350,
#    343,
#    0.32125367286973555,
#    0.428337471998306],
#   'L15-0566E-1185N_2265_3451_13': [6,
#    2674,
#    1303,
#    2515,
#    0.5834606153174776,
#    146,
#    298,
#    513,
#    0.26473254759746145,
#    0.47023222055014197],
#   'L15-0632E-0892N_2528_4620_13': [4,
#    25551,
#    32488,
#    38289,
#    0.4192847003995766,
#    36,
#    170,
#    97,
#    0.21238938053097345,
#    0.35091682875619956],
#   'L15-1015E-1062N_4061_3941_13': [7,
#    33798,
#    17633,
#    23032,
#    0.6243799706265414,
#    181,
#    629,
#    497,
#    0.24327956989247312,
#    0.475427408714914],
#   'L15-1200E-0847N_4802_4803_13': [6,
#    102684,
#    64789,
#    163630,
#    0.4734305085214633,
#    36,
#    177,
#    154,
#    0.17866004962779156,
#    0.3559683680738717],
#   'L15-1276E-1107N_5105_3761_13': [3,
#    30982,
#    15879,
#    42168,
#    0.5163193373940722,
#    68,
#    526,
#    649,
#    0.10373760488176964,
#    0.2875736649737374],
#   'L15-1438E-1134N_5753_3655_13': [25,
#    120074,
#    73104,
#    187766,
#    0.47932010426771093,
#    2,
#    332,
#    316,
#    0.006134969325153374,
#    0.029180866155104342],
#   'L15-1615E-1206N_6460_3366_13': [6,
#    46675,
#    24972,
#    36262,
#    0.6038787972882058,
#    29,
#    250,
#    209,
#    0.11218568665377177,
#    0.3217992160706492],
#   'L15-1690E-1211N_6763_3346_13': [7,
#    26074,
#    12744,
#    21561,
#    0.6031947994864262,
#    41,
#    177,
#    463,
#    0.11357340720221606,
#    0.3239131831199634],
#   'L15-1848E-0793N_7394_5018_13': [7,
#    5054,
#    3802,
#    7557,
#    0.47086225369171286,
#    155,
#    332,
#    728,
#    0.22627737226277372,
#    0.3871644676754218]})
