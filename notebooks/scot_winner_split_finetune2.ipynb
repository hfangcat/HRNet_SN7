# %% [markdown]
# # Evaluation Metrics: SCOT

# %%
from shapely.ops import cascaded_union
import matplotlib.pyplot as plt
import geopandas as gpd
import multiprocessing
import pandas as pd
import numpy as np
import skimage.io
import tqdm
import glob
import math
import gdal
import time
import sys
import os
import geopandas as gpd
from shapely import wkt

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
import matplotlib
# matplotlib.use('Agg') # non-interactive

import solaris as sol
from solaris.utils.core import _check_gdf_load
from solaris.raster.image import create_multiband_geotiff 

# import from data_postproc_funcs
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sn7_baseline_postproc_funcs import map_wrapper, multithread_polys, \
        calculate_iou, track_footprint_identifiers, \
        sn7_convert_geojsons_to_csv
import solaris.eval.scot as scot
# Out:
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
ground_truth = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7_csv/ground_truth.csv')
aois = [z.split('mosaic_')[-1] for z in ground_truth['filename'].values]
ground_truth['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in ground_truth['filename'].values]
ground_truth['timestep'] = timesteps
ground_truth = ground_truth.drop('filename', 1)

# %%
ground_truth.head()
# Out:
#      id                                           geometry  \
# 0  1131  POLYGON ((1022.739556749351 1023.915693833842,...
# 1   896  POLYGON ((839.4174400521442 1023.860588716227,...
# 2   607  POLYGON ((977.5393254966475 1021.220368818729,...
# 3   539  POLYGON ((804.8580670831725 1021.935737615102,...
# 4   769  POLYGON ((817.6027463246137 1022.111423592898,...
#
#                             aoi timestep
# 0  L15-0387E-1276N_1549_3087_13  2018_01
# 1  L15-0387E-1276N_1549_3087_13  2018_01
# 2  L15-0387E-1276N_1549_3087_13  2018_01
# 3  L15-0387E-1276N_1549_3087_13  2018_01
# 4  L15-0387E-1276N_1549_3087_13  2018_01

# %%
ground_truth['geometry'] = ground_truth['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(ground_truth, geometry = 'geometry')
print(gdf)
# Out:
#           id                                           geometry  \
# 0       1131  POLYGON ((1022.740 1023.916, 1021.780 1025.799...
# 1        896  POLYGON ((839.417 1023.861, 832.526 1024.057, ...
# 2        607  POLYGON ((977.539 1021.220, 976.830 1024.765, ...
# 3        539  POLYGON ((804.858 1021.936, 801.562 1024.604, ...
# 4        769  POLYGON ((817.603 1022.111, 814.501 1024.105, ...
# ...      ...                                                ...
# 953426   199  POLYGON ((16.975 27.234, 23.288 27.566, 23.158...
# 953427   215  POLYGON ((264.036 7.059, 267.359 7.059, 267.35...
# 953428   225  POLYGON ((269.021 3.875, 273.175 3.875, 273.17...
# 953429   648  POLYGON ((267.221 3.459, 267.221 1.659, 269.15...
# 953430   625  POLYGON ((268.467 0.829, 268.467 -0.833, 271.7...
#
#                                  aoi timestep
# 0       L15-0387E-1276N_1549_3087_13  2018_01
# 1       L15-0387E-1276N_1549_3087_13  2018_01
# 2       L15-0387E-1276N_1549_3087_13  2018_01
# 3       L15-0387E-1276N_1549_3087_13  2018_01
# 4       L15-0387E-1276N_1549_3087_13  2018_01
# ...                              ...      ...
# 953426  L15-1848E-0793N_7394_5018_13  2020_01
# 953427  L15-1848E-0793N_7394_5018_13  2020_01
# 953428  L15-1848E-0793N_7394_5018_13  2020_01
# 953429  L15-1848E-0793N_7394_5018_13  2020_01
# 953430  L15-1848E-0793N_7394_5018_13  2020_01
#
# [953431 rows x 4 columns]

# %%
pred = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7_csv/submission_hrnet_finetune2.csv')
aois = [z.split('mosaic_')[-1] for z in pred['filename'].values]
pred['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in pred['filename'].values]
pred['timestep'] = timesteps
pred = pred.drop('filename', 1)

# %%
pred.head()
# Out:
#    id                                           geometry  \
# 0   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 1   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 2   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 3   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
# 4   0  POLYGON (( 3 37.3,3 37.7,2.7 37.7,2.7 38.3,2.3...
#
#                             aoi timestep
# 0  L15-0632E-0892N_2528_4620_13  2018_01
# 1  L15-0632E-0892N_2528_4620_13  2018_02
# 2  L15-0632E-0892N_2528_4620_13  2018_03
# 3  L15-0632E-0892N_2528_4620_13  2018_04
# 4  L15-0632E-0892N_2528_4620_13  2018_05

# %%
pred['geometry'] = pred['geometry'].apply(wkt.loads)
pdf = gpd.GeoDataFrame(pred, geometry = 'geometry')
print(pdf)
# Out:
#           id                                           geometry  \
# 0          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 1          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 2          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 3          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# 4          0  POLYGON ((3.000 37.300, 3.000 37.700, 2.700 37...
# ...      ...                                                ...
# 663765  2363  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663766  2363  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663767  2363  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663768  2363  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 663769  2363  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
#
#                                  aoi timestep
# 0       L15-0632E-0892N_2528_4620_13  2018_01
# 1       L15-0632E-0892N_2528_4620_13  2018_02
# 2       L15-0632E-0892N_2528_4620_13  2018_03
# 3       L15-0632E-0892N_2528_4620_13  2018_04
# 4       L15-0632E-0892N_2528_4620_13  2018_05
# ...                              ...      ...
# 663765  L15-1690E-1211N_6763_3346_13  2019_05
# 663766  L15-1690E-1211N_6763_3346_13  2019_06
# 663767  L15-1690E-1211N_6763_3346_13  2019_07
# 663768  L15-1690E-1211N_6763_3346_13  2019_08
# 663769  L15-1690E-1211N_6763_3346_13  2019_09
#
# [663770 rows x 4 columns]

# %%
scot.scot_multi_aoi(gdf, pdf, verbose=True)
# Out:
# 1 / 10: AOI L15-0387E-1276N_1549_3087_13
# Matching footprints
#    1: F1 = 0.4356
#    2: F1 = 0.4655
#    3: F1 = 0.4692
#    4: F1 = 0.4712
#    5: F1 = 0.4678
#    6: F1 = 0.4680
#    7: F1 = 0.4670
#    8: F1 = 0.4685
#    9: F1 = 0.4705
#   10: F1 = 0.4702
#   11: F1 = 0.4589
#   12: F1 = 0.4544
#   13: F1 = 0.4686
#   14: F1 = 0.4711
#   15: F1 = 0.4701
#   16: F1 = 0.4695
#   17: F1 = 0.4705
#   18: F1 = 0.4713
#   19: F1 = 0.4709
#   20: F1 = 0.4604
#   21: F1 = 0.4565
#   22: F1 = 0.4465
# Identifying mismatches
# Tracking:
#     Mismatches: 4
#       True Pos: 14004
#      False Pos: 9148
#      False Neg: 23081
#    Track Score: 0.4650
# Change Detection:
#       True Pos: 161
#      False Pos: 406
#      False Neg: 346
#   Change Score: 0.2998
# Combined Score: 0.4188
#
# 2 / 10: AOI L15-0566E-1185N_2265_3451_13
# Matching footprints
#    1: F1 = 0.3077
#    2: F1 = 0.2647
#    3: F1 = 0.2609
#    4: F1 = 0.2597
#    5: F1 = 0.3000
#    6: F1 = 0.3182
#    7: F1 = 0.3191
#    8: F1 = 0.3357
#    9: F1 = 0.3553
#   10: F1 = 0.5120
#   11: F1 = 0.5367
#   12: F1 = 0.5383
#   13: F1 = 0.6288
#   14: F1 = 0.6140
#   15: F1 = 0.5779
#   16: F1 = 0.5810
#   17: F1 = 0.6338
#   18: F1 = 0.6256
#   19: F1 = 0.6275
#   20: F1 = 0.6191
#   21: F1 = 0.6160
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 2699
#      False Pos: 1439
#      False Neg: 2490
#    Track Score: 0.5787
# Change Detection:
#       True Pos: 148
#      False Pos: 325
#      False Neg: 511
#   Change Score: 0.2615
# Combined Score: 0.4657
#
# 3 / 10: AOI L15-0632E-0892N_2528_4620_13
# Matching footprints
#    1: F1 = 0.4137
#    2: F1 = 0.4124
#    3: F1 = 0.4134
#    4: F1 = 0.4136
#    5: F1 = 0.4137
#    6: F1 = 0.4129
#    7: F1 = 0.4140
#    8: F1 = 0.4148
#    9: F1 = 0.4170
#   10: F1 = 0.4171
#   11: F1 = 0.4171
#   12: F1 = 0.4175
#   13: F1 = 0.4192
#   14: F1 = 0.4218
#   15: F1 = 0.4227
#   16: F1 = 0.4238
#   17: F1 = 0.4238
#   18: F1 = 0.4241
#   19: F1 = 0.4240
#   20: F1 = 0.4245
#   21: F1 = 0.4252
#   22: F1 = 0.4246
#   23: F1 = 0.4248
#   24: F1 = 0.4242
#   25: F1 = 0.4231
# Identifying mismatches
# Tracking:
#     Mismatches: 5
#       True Pos: 25571
#      False Pos: 32548
#      False Neg: 38269
#    Track Score: 0.4193
# Change Detection:
#       True Pos: 36
#      False Pos: 235
#      False Neg: 97
#   Change Score: 0.1782
# Combined Score: 0.3300
#
# 4 / 10: AOI L15-1015E-1062N_4061_3941_13
# Matching footprints
#    1: F1 = 0.6265
#    2: F1 = 0.6287
#    3: F1 = 0.6301
#    4: F1 = 0.6330
#    5: F1 = 0.6248
#    6: F1 = 0.6275
#    7: F1 = 0.6324
#    8: F1 = 0.6293
#    9: F1 = 0.6190
#   10: F1 = 0.6255
#   11: F1 = 0.6247
#   12: F1 = 0.6239
#   13: F1 = 0.6214
#   14: F1 = 0.6188
#   15: F1 = 0.6223
#   16: F1 = 0.6182
#   17: F1 = 0.6173
#   18: F1 = 0.6151
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 33828
#      False Pos: 17786
#      False Neg: 23002
#    Track Score: 0.6239
# Change Detection:
#       True Pos: 186
#      False Pos: 781
#      False Neg: 492
#   Change Score: 0.2261
# Combined Score: 0.4615
#
# 5 / 10: AOI L15-1200E-0847N_4802_4803_13
# Matching footprints
#    1: F1 = 0.4691
#    2: F1 = 0.4691
#    3: F1 = 0.4696
#    4: F1 = 0.4867
#    5: F1 = 0.4701
#    6: F1 = 0.4704
#    7: F1 = 0.4707
#    8: F1 = 0.4708
#    9: F1 = 0.4709
#   10: F1 = 0.4710
#   11: F1 = 0.4711
#   12: F1 = 0.4715
#   13: F1 = 0.4717
#   14: F1 = 0.4717
#   15: F1 = 0.4720
#   16: F1 = 0.4719
#   17: F1 = 0.4724
#   18: F1 = 0.4724
#   19: F1 = 0.4730
#   20: F1 = 0.4736
#   21: F1 = 0.4736
#   22: F1 = 0.4734
#   23: F1 = 0.4740
#   24: F1 = 0.4735
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 102392
#      False Pos: 64995
#      False Neg: 163922
#    Track Score: 0.4722
# Change Detection:
#       True Pos: 36
#      False Pos: 227
#      False Neg: 154
#   Change Score: 0.1589
# Combined Score: 0.3387
#
# 6 / 10: AOI L15-1276E-1107N_5105_3761_13
# Matching footprints
#    1: F1 = 0.5173
#    2: F1 = 0.5164
#    3: F1 = 0.5161
#    4: F1 = 0.5169
#    5: F1 = 0.5171
#    6: F1 = 0.5167
#    7: F1 = 0.5174
#    8: F1 = 0.5142
#    9: F1 = 0.5145
#   10: F1 = 0.5181
#   11: F1 = 0.5187
#   12: F1 = 0.5170
#   13: F1 = 0.5153
#   14: F1 = 0.5166
#   15: F1 = 0.5140
#   16: F1 = 0.5135
#   17: F1 = 0.5136
#   18: F1 = 0.5138
#   19: F1 = 0.5135
#   20: F1 = 0.5166
#   21: F1 = 0.5161
#   22: F1 = 0.5173
#   23: F1 = 0.5172
#   24: F1 = 0.5148
#   25: F1 = 0.5122
# Identifying mismatches
# Tracking:
#     Mismatches: 2
#       True Pos: 30982
#      False Pos: 16021
#      False Neg: 42168
#    Track Score: 0.5157
# Change Detection:
#       True Pos: 73
#      False Pos: 599
#      False Neg: 644
#   Change Score: 0.1051
# Combined Score: 0.2895
#
# 7 / 10: AOI L15-1438E-1134N_5753_3655_13
# Matching footprints
#    1: F1 = 0.4761
#    2: F1 = 0.4774
#    3: F1 = 0.4794
#    4: F1 = 0.4797
#    5: F1 = 0.4798
#    6: F1 = 0.4555
#    7: F1 = 0.4835
#    8: F1 = 0.4805
#    9: F1 = 0.4813
#   10: F1 = 0.4813
#   11: F1 = 0.4817
#   12: F1 = 0.4816
#   13: F1 = 0.4813
#   14: F1 = 0.4812
#   15: F1 = 0.4807
#   16: F1 = 0.4807
#   17: F1 = 0.4775
#   18: F1 = 0.4619
#   19: F1 = 0.4802
#   20: F1 = 0.4802
#   21: F1 = 0.4800
#   22: F1 = 0.4798
# Identifying mismatches
# Tracking:
#     Mismatches: 24
#       True Pos: 119904
#      False Pos: 72973
#      False Neg: 187936
#    Track Score: 0.4789
# Change Detection:
#       True Pos: 2
#      False Pos: 658
#      False Neg: 316
#   Change Score: 0.0041
# Combined Score: 0.0198
#
# 8 / 10: AOI L15-1615E-1206N_6460_3366_13
# Matching footprints
#    1: F1 = 0.5827
#    2: F1 = 0.5837
#    3: F1 = 0.5830
#    4: F1 = 0.6115
#    5: F1 = 0.5850
#    6: F1 = 0.5857
#    7: F1 = 0.5864
#    8: F1 = 0.5982
#    9: F1 = 0.5997
#   10: F1 = 0.6109
#   11: F1 = 0.6129
#   12: F1 = 0.6142
#   13: F1 = 0.6134
#   14: F1 = 0.6038
#   15: F1 = 0.6126
#   16: F1 = 0.5820
#   17: F1 = 0.6123
#   18: F1 = 0.6137
#   19: F1 = 0.6133
#   20: F1 = 0.6141
#   21: F1 = 0.6130
#   22: F1 = 0.6118
#   23: F1 = 0.6115
#   24: F1 = 0.6142
#   25: F1 = 0.6086
#   26: F1 = 0.5993
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 46608
#      False Pos: 25079
#      False Neg: 36329
#    Track Score: 0.6029
# Change Detection:
#       True Pos: 37
#      False Pos: 334
#      False Neg: 201
#   Change Score: 0.1215
# Combined Score: 0.3364
#
# 9 / 10: AOI L15-1690E-1211N_6763_3346_13
# Matching footprints
#    1: F1 = 0.6146
#    2: F1 = 0.6140
#    3: F1 = 0.6131
#    4: F1 = 0.6141
#    5: F1 = 0.6145
#    6: F1 = 0.6134
#    7: F1 = 0.6144
#    8: F1 = 0.6147
#    9: F1 = 0.6117
#   10: F1 = 0.6125
#   11: F1 = 0.6120
#   12: F1 = 0.6133
#   13: F1 = 0.6102
#   14: F1 = 0.6055
#   15: F1 = 0.5925
#   16: F1 = 0.5755
#   17: F1 = 0.5950
#   18: F1 = 0.5951
#   19: F1 = 0.5950
#   20: F1 = 0.5921
#   21: F1 = 0.5838
#   22: F1 = 0.5823
#   23: F1 = 0.5806
#   24: F1 = 0.5732
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 26027
#      False Pos: 12818
#      False Neg: 21608
#    Track Score: 0.6019
# Change Detection:
#       True Pos: 42
#      False Pos: 227
#      False Neg: 462
#   Change Score: 0.1087
# Combined Score: 0.3155
#
# 10 / 10: AOI L15-1848E-0793N_7394_5018_13
# Matching footprints
#    1: F1 = 0.5177
#    2: F1 = 0.5237
#    3: F1 = 0.4675
#    4: F1 = 0.4698
#    5: F1 = 0.4431
#    6: F1 = 0.4712
#    7: F1 = 0.4705
#    8: F1 = 0.4689
#    9: F1 = 0.7407
#   10: F1 = 0.7586
#   11: F1 = 0.4212
#   12: F1 = 0.4251
#   13: F1 = 0.4588
#   14: F1 = 0.4586
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 5035
#      False Pos: 3913
#      False Neg: 7576
#    Track Score: 0.4671
# Change Detection:
#       True Pos: 161
#      False Pos: 381
#      False Neg: 722
#   Change Score: 0.2260
# Combined Score: 0.3849
# Overall score: 0.336090
# (0.33608995797554664,
#  {'L15-0387E-1276N_1549_3087_13': [4,
#    14004,
#    9148,
#    23081,
#    0.4649633945913641,
#    161,
#    406,
#    346,
#    0.29981378026070765,
#    0.4188225034924723],
#   'L15-0566E-1185N_2265_3451_13': [6,
#    2699,
#    1439,
#    2490,
#    0.5787498659804867,
#    148,
#    325,
#    511,
#    0.26148409893992935,
#    0.46573264876204],
#   'L15-0632E-0892N_2528_4620_13': [5,
#    25571,
#    32548,
#    38269,
#    0.4193376462581687,
#    36,
#    235,
#    97,
#    0.1782178217821782,
#    0.33003379369141406],
#   'L15-1015E-1062N_4061_3941_13': [7,
#    33828,
#    17786,
#    23002,
#    0.6238796060639593,
#    186,
#    781,
#    492,
#    0.22613981762917934,
#    0.4615298082887421],
#   'L15-1200E-0847N_4802_4803_13': [6,
#    102392,
#    64995,
#    163922,
#    0.47217783680461883,
#    36,
#    227,
#    154,
#    0.15894039735099338,
#    0.33868337576394386],
#   'L15-1276E-1107N_5105_3761_13': [2,
#    30982,
#    16021,
#    42168,
#    0.5157091375163333,
#    73,
#    599,
#    644,
#    0.10511159107271419,
#    0.28951925118442223],
#   'L15-1438E-1134N_5753_3655_13': [24,
#    119904,
#    72973,
#    187936,
#    0.47892921550496587,
#    2,
#    658,
#    316,
#    0.00408997955010225,
#    0.019774416235497624],
#   'L15-1615E-1206N_6460_3366_13': [7,
#    46608,
#    25079,
#    36329,
#    0.6028559602649006,
#    37,
#    334,
#    201,
#    0.12151067323481117,
#    0.3363647910659744],
#   'L15-1690E-1211N_6763_3346_13': [7,
#    26027,
#    12818,
#    21608,
#    0.6019195189639223,
#    42,
#    227,
#    462,
#    0.10866752910737387,
#    0.3155014511720626],
#   'L15-1848E-0793N_7394_5018_13': [7,
#    5035,
#    3913,
#    7576,
#    0.46709031031123893,
#    161,
#    381,
#    722,
#    0.22596491228070176,
#    0.3849375400988971]})
