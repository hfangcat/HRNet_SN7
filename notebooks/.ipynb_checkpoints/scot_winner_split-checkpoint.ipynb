# %% [markdown]
# # Evaluation Metrics: SCOT

# %%
from shapely.ops import cascaded_union
import matplotlib.pyplot as plt
import geopandas as gpd
import multiprocessing
import pandas as pd
import numpy as np
import skimage.io
import tqdm
import glob
import math
import gdal
import time
import sys
import os
import geopandas as gpd
from shapely import wkt

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
import matplotlib
# matplotlib.use('Agg') # non-interactive

import solaris as sol
from solaris.utils.core import _check_gdf_load
from solaris.raster.image import create_multiband_geotiff 

# import from data_postproc_funcs
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sn7_baseline_postproc_funcs import map_wrapper, multithread_polys, \
        calculate_iou, track_footprint_identifiers, \
        sn7_convert_geojsons_to_csv
import solaris.eval.scot as scot
# Out:
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
ground_truth = pd.read_csv('/local_storage/users/hfang/inference_winner_split/sn7_baseline_preds/csvs/ground_truth.csv')
aois = [z.split('mosaic_')[-1] for z in ground_truth['filename'].values]
ground_truth['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in ground_truth['filename'].values]
ground_truth['timestep'] = timesteps
ground_truth = ground_truth.drop('filename', 1)

# %%
ground_truth.head()
# Out:
#      id                                           geometry  \
# 0  1131  POLYGON ((1022.739556749351 1023.915693833842,...
# 1   896  POLYGON ((839.4174400521442 1023.860588716227,...
# 2   607  POLYGON ((977.5393254966475 1021.220368818729,...
# 3   539  POLYGON ((804.8580670831725 1021.935737615102,...
# 4   769  POLYGON ((817.6027463246137 1022.111423592898,...
#
#                             aoi timestep
# 0  L15-0387E-1276N_1549_3087_13  2018_01
# 1  L15-0387E-1276N_1549_3087_13  2018_01
# 2  L15-0387E-1276N_1549_3087_13  2018_01
# 3  L15-0387E-1276N_1549_3087_13  2018_01
# 4  L15-0387E-1276N_1549_3087_13  2018_01

# %%
ground_truth['geometry'] = ground_truth['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(ground_truth, geometry = 'geometry')
print(gdf)
# Out:
#           id                                           geometry  \
# 0       1131  POLYGON ((1022.740 1023.916, 1021.780 1025.799...
# 1        896  POLYGON ((839.417 1023.861, 832.526 1024.057, ...
# 2        607  POLYGON ((977.539 1021.220, 976.830 1024.765, ...
# 3        539  POLYGON ((804.858 1021.936, 801.562 1024.604, ...
# 4        769  POLYGON ((817.603 1022.111, 814.501 1024.105, ...
# ...      ...                                                ...
# 953426   199  POLYGON ((16.975 27.234, 23.288 27.566, 23.158...
# 953427   215  POLYGON ((264.036 7.059, 267.359 7.059, 267.35...
# 953428   225  POLYGON ((269.021 3.875, 273.175 3.875, 273.17...
# 953429   648  POLYGON ((267.221 3.459, 267.221 1.659, 269.15...
# 953430   625  POLYGON ((268.467 0.829, 268.467 -0.833, 271.7...
#
#                                  aoi timestep
# 0       L15-0387E-1276N_1549_3087_13  2018_01
# 1       L15-0387E-1276N_1549_3087_13  2018_01
# 2       L15-0387E-1276N_1549_3087_13  2018_01
# 3       L15-0387E-1276N_1549_3087_13  2018_01
# 4       L15-0387E-1276N_1549_3087_13  2018_01
# ...                              ...      ...
# 953426  L15-1848E-0793N_7394_5018_13  2020_01
# 953427  L15-1848E-0793N_7394_5018_13  2020_01
# 953428  L15-1848E-0793N_7394_5018_13  2020_01
# 953429  L15-1848E-0793N_7394_5018_13  2020_01
# 953430  L15-1848E-0793N_7394_5018_13  2020_01
#
# [953431 rows x 4 columns]

# %%
pred = pd.read_csv('/local_storage/users/hfang/inference_winner_split/sn7_baseline_preds/csvs/sn7_baseline_predictions.csv')
aois = [z.split('mosaic_')[-1] for z in pred['filename'].values]
pred['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in pred['filename'].values]
pred['timestep'] = timesteps
pred = pred.drop('filename', 1)

# %%
pred.head()
# Out:
#    id                                           geometry  \
# 0   0  POLYGON ((482 509, 482 510, 483 510, 483 511, ...
# 1   1  POLYGON ((120 0, 120 1, 121 1, 121 2, 120 2, 1...
# 2   2  POLYGON ((200 793, 200 794, 199 794, 189 794, ...
# 3   3  POLYGON ((508 47, 508 48, 507 48, 507 50, 506 ...
# 4   4  POLYGON ((533 0, 533 3, 532 3, 532 5, 531 5, 5...
#
#                             aoi timestep
# 0  L15-0387E-1276N_1549_3087_13  2018_01
# 1  L15-0387E-1276N_1549_3087_13  2018_01
# 2  L15-0387E-1276N_1549_3087_13  2018_01
# 3  L15-0387E-1276N_1549_3087_13  2018_01
# 4  L15-0387E-1276N_1549_3087_13  2018_01

# %%
pred['geometry'] = pred['geometry'].apply(wkt.loads)
pdf = gpd.GeoDataFrame(pred, geometry = 'geometry')
print(pdf)
# Out:
#           id                                           geometry  \
# 0          0  POLYGON ((482.000 509.000, 482.000 510.000, 48...
# 1          1  POLYGON ((120.000 0.000, 120.000 1.000, 121.00...
# 2          2  POLYGON ((200.000 793.000, 200.000 794.000, 19...
# 3          3  POLYGON ((508.000 47.000, 508.000 48.000, 507....
# 4          4  POLYGON ((533.000 0.000, 533.000 3.000, 532.00...
# ...      ...                                                ...
# 396741  1047  POLYGON ((647.000 566.000, 647.000 568.000, 64...
# 396742  1721  POLYGON ((857.000 632.000, 857.000 634.000, 85...
# 396743  1722  POLYGON ((705.000 577.000, 705.000 579.000, 70...
# 396744   275  POLYGON ((340.000 587.000, 340.000 589.000, 34...
# 396745   265  POLYGON ((378.000 878.000, 378.000 880.000, 38...
#
#                                  aoi timestep
# 0       L15-0387E-1276N_1549_3087_13  2018_01
# 1       L15-0387E-1276N_1549_3087_13  2018_01
# 2       L15-0387E-1276N_1549_3087_13  2018_01
# 3       L15-0387E-1276N_1549_3087_13  2018_01
# 4       L15-0387E-1276N_1549_3087_13  2018_01
# ...                              ...      ...
# 396741  L15-1848E-0793N_7394_5018_13  2020_01
# 396742  L15-1848E-0793N_7394_5018_13  2020_01
# 396743  L15-1848E-0793N_7394_5018_13  2020_01
# 396744  L15-1848E-0793N_7394_5018_13  2020_01
# 396745  L15-1848E-0793N_7394_5018_13  2020_01
#
# [396746 rows x 4 columns]

# %%
scot.scot_multi_aoi(gdf, pdf, verbose=True)
# Out:
# 1 / 10: AOI L15-0387E-1276N_1549_3087_13
# Matching footprints
#    1: F1 = 0.1260
#    2: F1 = 0.3411
#    3: F1 = 0.2938
#    4: F1 = 0.3156
#    5: F1 = 0.2829
#    6: F1 = 0.3030
#    7: F1 = 0.2255
#    8: F1 = 0.3088
#    9: F1 = 0.3304
#   10: F1 = 0.3192
#   11: F1 = 0.2750
#   12: F1 = 0.2709
#   13: F1 = 0.3034
#   14: F1 = 0.3220
#   15: F1 = 0.3305
#   16: F1 = 0.3057
#   17: F1 = 0.2990
#   18: F1 = 0.3154
#   19: F1 = 0.2326
#   20: F1 = 0.2874
#   21: F1 = 0.2898
#   22: F1 = 0.2720
# Identifying mismatches
# Tracking:
#     Mismatches: 1231
#       True Pos: 6680
#      False Pos: 10789
#      False Neg: 30405
#    Track Score: 0.2449
# Change Detection:
#       True Pos: 88
#      False Pos: 3086
#      False Neg: 419
#   Change Score: 0.0478
# Combined Score: 0.1342
#
# 2 / 10: AOI L15-0566E-1185N_2265_3451_13
# Matching footprints
#    1: F1 = 0.5106
#    2: F1 = 0.1765
#    3: F1 = 0.2791
#    4: F1 = 0.0444
#    5: F1 = 0.0357
#    6: F1 = 0.0339
#    7: F1 = 0.2000
#    8: F1 = 0.3784
#    9: F1 = 0.2222
#   10: F1 = 0.5106
#   11: F1 = 0.5143
#   12: F1 = 0.4987
#   13: F1 = 0.5617
#   14: F1 = 0.3413
#   15: F1 = 0.0825
#   16: F1 = 0.3858
#   17: F1 = 0.5983
#   18: F1 = 0.6190
#   19: F1 = 0.5602
#   20: F1 = 0.5717
#   21: F1 = 0.5960
# Identifying mismatches
# Tracking:
#     Mismatches: 303
#       True Pos: 1824
#      False Pos: 1510
#      False Neg: 3365
#    Track Score: 0.4280
# Change Detection:
#       True Pos: 184
#      False Pos: 946
#      False Neg: 475
#   Change Score: 0.2057
# Combined Score: 0.3519
#
# 3 / 10: AOI L15-0632E-0892N_2528_4620_13
# Matching footprints
#    1: F1 = 0.3405
#    2: F1 = 0.3151
#    3: F1 = 0.3258
#    4: F1 = 0.3138
#    5: F1 = 0.3309
#    6: F1 = 0.3325
#    7: F1 = 0.3517
#    8: F1 = 0.3238
#    9: F1 = 0.3243
#   10: F1 = 0.3476
#   11: F1 = 0.2471
#   12: F1 = 0.2993
#   13: F1 = 0.3319
#   14: F1 = 0.3986
#   15: F1 = 0.3539
#   16: F1 = 0.3707
#   17: F1 = 0.3955
#   18: F1 = 0.3570
#   19: F1 = 0.3379
#   20: F1 = 0.3102
#   21: F1 = 0.3365
#   22: F1 = 0.3772
#   23: F1 = 0.3514
#   24: F1 = 0.3781
#   25: F1 = 0.4116
# Identifying mismatches
# Tracking:
#     Mismatches: 1242
#       True Pos: 13979
#      False Pos: 10724
#      False Neg: 49861
#    Track Score: 0.3158
# Change Detection:
#       True Pos: 54
#      False Pos: 2897
#      False Neg: 79
#   Change Score: 0.0350
# Combined Score: 0.1213
#
# 4 / 10: AOI L15-1015E-1062N_4061_3941_13
# Matching footprints
#    1: F1 = 0.5557
#    2: F1 = 0.5190
#    3: F1 = 0.5311
#    4: F1 = 0.5740
#    5: F1 = 0.5732
#    6: F1 = 0.5477
#    7: F1 = 0.5738
#    8: F1 = 0.5093
#    9: F1 = 0.3028
#   10: F1 = 0.5244
#   11: F1 = 0.5057
#   12: F1 = 0.5045
#   13: F1 = 0.5366
#   14: F1 = 0.5310
#   15: F1 = 0.5787
#   16: F1 = 0.5260
#   17: F1 = 0.5255
#   18: F1 = 0.4913
# Identifying mismatches
# Tracking:
#     Mismatches: 1602
#       True Pos: 21388
#      False Pos: 9373
#      False Neg: 35442
#    Track Score: 0.4884
# Change Detection:
#       True Pos: 239
#      False Pos: 3397
#      False Neg: 439
#   Change Score: 0.1108
# Combined Score: 0.2904
#
# 5 / 10: AOI L15-1200E-0847N_4802_4803_13
# Matching footprints
#    1: F1 = 0.3549
#    2: F1 = 0.3354
#    3: F1 = 0.3496
#    4: F1 = 0.3268
#    5: F1 = 0.3015
#    6: F1 = 0.3062
#    7: F1 = 0.2861
#    8: F1 = 0.3307
#    9: F1 = 0.3391
#   10: F1 = 0.3124
#   11: F1 = 0.3484
#   12: F1 = 0.3165
#   13: F1 = 0.3500
#   14: F1 = 0.3267
#   15: F1 = 0.3315
#   16: F1 = 0.3058
#   17: F1 = 0.3079
#   18: F1 = 0.2928
#   19: F1 = 0.3060
#   20: F1 = 0.2944
#   21: F1 = 0.3116
#   22: F1 = 0.3547
#   23: F1 = 0.3074
#   24: F1 = 0.3093
# Identifying mismatches
# Tracking:
#     Mismatches: 7317
#       True Pos: 52685
#      False Pos: 54595
#      False Neg: 213629
#    Track Score: 0.2820
# Change Detection:
#       True Pos: 40
#      False Pos: 10823
#      False Neg: 150
#   Change Score: 0.0072
# Combined Score: 0.0328
#
# 6 / 10: AOI L15-1276E-1107N_5105_3761_13
# Matching footprints
#    1: F1 = 0.4651
#    2: F1 = 0.4422
#    3: F1 = 0.4250
#    4: F1 = 0.3776
#    5: F1 = 0.3769
#    6: F1 = 0.3380
#    7: F1 = 0.3922
#    8: F1 = 0.4028
#    9: F1 = 0.4074
#   10: F1 = 0.4324
#   11: F1 = 0.4190
#   12: F1 = 0.4094
#   13: F1 = 0.4104
#   14: F1 = 0.3715
#   15: F1 = 0.4198
#   16: F1 = 0.4080
#   17: F1 = 0.4155
#   18: F1 = 0.4667
#   19: F1 = 0.2849
#   20: F1 = 0.4154
#   21: F1 = 0.4179
#   22: F1 = 0.4421
#   23: F1 = 0.4173
#   24: F1 = 0.3761
#   25: F1 = 0.3825
# Identifying mismatches
# Tracking:
#     Mismatches: 1967
#       True Pos: 19888
#      False Pos: 14684
#      False Neg: 53262
#    Track Score: 0.3692
# Change Detection:
#       True Pos: 144
#      False Pos: 3708
#      False Neg: 573
#   Change Score: 0.0630
# Combined Score: 0.1873
#
# 7 / 10: AOI L15-1438E-1134N_5753_3655_13
# Matching footprints
#    1: F1 = 0.4135
#    2: F1 = 0.3889
#    3: F1 = 0.3942
#    4: F1 = 0.3674
#    5: F1 = 0.3531
#    6: F1 = 0.3568
#    7: F1 = 0.3503
#    8: F1 = 0.3748
#    9: F1 = 0.3899
#   10: F1 = 0.3850
#   11: F1 = 0.3623
#   12: F1 = 0.3416
#   13: F1 = 0.3184
#   14: F1 = 0.3264
#   15: F1 = 0.3286
#   16: F1 = 0.3434
#   17: F1 = 0.3441
#   18: F1 = 0.3372
#   19: F1 = 0.3731
#   20: F1 = 0.3653
#   21: F1 = 0.3685
#   22: F1 = 0.3671
# Identifying mismatches
# Tracking:
#     Mismatches: 6531
#       True Pos: 69535
#      False Pos: 42164
#      False Neg: 238305
#    Track Score: 0.3315
# Change Detection:
#       True Pos: 18
#      False Pos: 12561
#      False Neg: 300
#   Change Score: 0.0028
# Combined Score: 0.0135
#
# 8 / 10: AOI L15-1615E-1206N_6460_3366_13
# Matching footprints
#    1: F1 = 0.4759
#    2: F1 = 0.4522
#    3: F1 = 0.4891
#    4: F1 = 0.2003
#    5: F1 = 0.3646
#    6: F1 = 0.3251
#    7: F1 = 0.3973
#    8: F1 = 0.3966
#    9: F1 = 0.4491
#   10: F1 = 0.4196
#   11: F1 = 0.4866
#   12: F1 = 0.3951
#   13: F1 = 0.4593
#   14: F1 = 0.3864
#   15: F1 = 0.4259
#   16: F1 = 0.2809
#   17: F1 = 0.3230
#   18: F1 = 0.2970
#   19: F1 = 0.2760
#   20: F1 = 0.4047
#   21: F1 = 0.4241
#   22: F1 = 0.3321
#   23: F1 = 0.4265
#   24: F1 = 0.4083
#   25: F1 = 0.4114
#   26: F1 = 0.2948
# Identifying mismatches
# Tracking:
#     Mismatches: 3282
#       True Pos: 20674
#      False Pos: 18576
#      False Neg: 62263
#    Track Score: 0.3384
# Change Detection:
#       True Pos: 51
#      False Pos: 5619
#      False Neg: 187
#   Change Score: 0.0173
# Combined Score: 0.0717
#
# 9 / 10: AOI L15-1690E-1211N_6763_3346_13
# Matching footprints
#    1: F1 = 0.5305
#    2: F1 = 0.5190
#    3: F1 = 0.3883
#    4: F1 = 0.3371
#    5: F1 = 0.3487
#    6: F1 = 0.3974
#    7: F1 = 0.4603
#    8: F1 = 0.4361
#    9: F1 = 0.3489
#   10: F1 = 0.4504
#   11: F1 = 0.4490
#   12: F1 = 0.4251
#   13: F1 = 0.4660
#   14: F1 = 0.4190
#   15: F1 = 0.3777
#   16: F1 = 0.2217
#   17: F1 = 0.3476
#   18: F1 = 0.3943
#   19: F1 = 0.4244
#   20: F1 = 0.4055
#   21: F1 = 0.3966
#   22: F1 = 0.4015
#   23: F1 = 0.3946
#   24: F1 = 0.3722
# Identifying mismatches
# Tracking:
#     Mismatches: 1377
#       True Pos: 12969
#      False Pos: 9315
#      False Neg: 34666
#    Track Score: 0.3710
# Change Detection:
#       True Pos: 93
#      False Pos: 2638
#      False Neg: 411
#   Change Score: 0.0575
# Combined Score: 0.1775
#
# 10 / 10: AOI L15-1848E-0793N_7394_5018_13
# Matching footprints
#    1: F1 = 0.4348
#    2: F1 = 0.4377
#    3: F1 = 0.3182
#    4: F1 = 0.3664
#    5: F1 = 0.3308
#    6: F1 = 0.3776
#    7: F1 = 0.3748
#    8: F1 = 0.3754
#    9: F1 = 0.4375
#   10: F1 = 0.3333
#   11: F1 = 0.2915
#   12: F1 = 0.2527
#   13: F1 = 0.3308
#   14: F1 = 0.3195
# Identifying mismatches
# Tracking:
#     Mismatches: 440
#       True Pos: 2719
#      False Pos: 2675
#      False Neg: 9892
#    Track Score: 0.3020
# Change Detection:
#       True Pos: 180
#      False Pos: 1184
#      False Neg: 703
#   Change Score: 0.1602
# Combined Score: 0.2566
# Overall score: 0.163726
# (0.1637261990488127,
#  {'L15-0387E-1276N_1549_3087_13': [1231,
#    6680,
#    10789,
#    30405,
#    0.24489496645525535,
#    88,
#    3086,
#    419,
#    0.047813094267862,
#    0.13423429364683412],
#   'L15-0566E-1185N_2265_3451_13': [303,
#    1824,
#    1510,
#    3365,
#    0.42801830341429076,
#    184,
#    946,
#    475,
#    0.20570150922302963,
#    0.3519439466849216],
#   'L15-0632E-0892N_2528_4620_13': [1242,
#    13979,
#    10724,
#    49861,
#    0.31575618625978336,
#    54,
#    2897,
#    79,
#    0.03501945525291829,
#    0.12128987152303043],
#   'L15-1015E-1062N_4061_3941_13': [1602,
#    21388,
#    9373,
#    35442,
#    0.48836067632519325,
#    239,
#    3397,
#    439,
#    0.11080203987019008,
#    0.2904313511217999],
#   'L15-1200E-0847N_4802_4803_13': [7317,
#    52685,
#    54595,
#    213629,
#    0.28204414417790435,
#    40,
#    10823,
#    150,
#    0.007237853976296028,
#    0.032820313091988476],
#   'L15-1276E-1107N_5105_3761_13': [1967,
#    19888,
#    14684,
#    53262,
#    0.3692467648205566,
#    144,
#    3708,
#    573,
#    0.06303348653972422,
#    0.18728382269435198],
#   'L15-1438E-1134N_5753_3655_13': [6531,
#    69535,
#    42164,
#    238305,
#    0.3314828895525803,
#    18,
#    12561,
#    300,
#    0.0027913468248429866,
#    0.01350194607343903],
#   'L15-1615E-1206N_6460_3366_13': [3282,
#    20674,
#    18576,
#    62263,
#    0.3383993387185216,
#    51,
#    5619,
#    187,
#    0.017264725795531483,
#    0.07169289011202563],
#   'L15-1690E-1211N_6763_3346_13': [1377,
#    12969,
#    9315,
#    34666,
#    0.3709721248873697,
#    93,
#    2638,
#    411,
#    0.05749613601236476,
#    0.17746257635392243],
#   'L15-1848E-0793N_7394_5018_13': [440,
#    2719,
#    2675,
#    9892,
#    0.30202721466259375,
#    180,
#    1184,
#    703,
#    0.1602136181575434,
#    0.2566009791858133]})
