# %% [markdown]
# # Evaluation Metrics: SCOT

# %%
from shapely.ops import cascaded_union
import matplotlib.pyplot as plt
import geopandas as gpd
import multiprocessing
import pandas as pd
import numpy as np
import skimage.io
import tqdm
import glob
import math
import gdal
import time
import sys
import os
import geopandas as gpd
from shapely import wkt

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
import matplotlib
# matplotlib.use('Agg') # non-interactive

import solaris as sol
from solaris.utils.core import _check_gdf_load
from solaris.raster.image import create_multiband_geotiff 

# import from data_postproc_funcs
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sn7_baseline_postproc_funcs import map_wrapper, multithread_polys, \
        calculate_iou, track_footprint_identifiers, \
        sn7_convert_geojsons_to_csv
import solaris.eval.scot as scot
# Out:
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Midgard/home/hfang/miniconda3/envs/solaris/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
ground_truth = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7_csv/ground_truth.csv')
aois = [z.split('mosaic_')[-1] for z in ground_truth['filename'].values]
ground_truth['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in ground_truth['filename'].values]
ground_truth['timestep'] = timesteps
ground_truth = ground_truth.drop('filename', 1)

# %%
ground_truth.head()
# Out:
#      id                                           geometry  \
# 0  1131  POLYGON ((1022.739556749351 1023.915693833842,...
# 1   896  POLYGON ((839.4174400521442 1023.860588716227,...
# 2   607  POLYGON ((977.5393254966475 1021.220368818729,...
# 3   539  POLYGON ((804.8580670831725 1021.935737615102,...
# 4   769  POLYGON ((817.6027463246137 1022.111423592898,...
#
#                             aoi timestep
# 0  L15-0387E-1276N_1549_3087_13  2018_01
# 1  L15-0387E-1276N_1549_3087_13  2018_01
# 2  L15-0387E-1276N_1549_3087_13  2018_01
# 3  L15-0387E-1276N_1549_3087_13  2018_01
# 4  L15-0387E-1276N_1549_3087_13  2018_01

# %%
ground_truth['geometry'] = ground_truth['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(ground_truth, geometry = 'geometry')
print(gdf)
# Out:
#           id                                           geometry  \
# 0       1131  POLYGON ((1022.740 1023.916, 1021.780 1025.799...
# 1        896  POLYGON ((839.417 1023.861, 832.526 1024.057, ...
# 2        607  POLYGON ((977.539 1021.220, 976.830 1024.765, ...
# 3        539  POLYGON ((804.858 1021.936, 801.562 1024.604, ...
# 4        769  POLYGON ((817.603 1022.111, 814.501 1024.105, ...
# ...      ...                                                ...
# 953426   199  POLYGON ((16.975 27.234, 23.288 27.566, 23.158...
# 953427   215  POLYGON ((264.036 7.059, 267.359 7.059, 267.35...
# 953428   225  POLYGON ((269.021 3.875, 273.175 3.875, 273.17...
# 953429   648  POLYGON ((267.221 3.459, 267.221 1.659, 269.15...
# 953430   625  POLYGON ((268.467 0.829, 268.467 -0.833, 271.7...
#
#                                  aoi timestep
# 0       L15-0387E-1276N_1549_3087_13  2018_01
# 1       L15-0387E-1276N_1549_3087_13  2018_01
# 2       L15-0387E-1276N_1549_3087_13  2018_01
# 3       L15-0387E-1276N_1549_3087_13  2018_01
# 4       L15-0387E-1276N_1549_3087_13  2018_01
# ...                              ...      ...
# 953426  L15-1848E-0793N_7394_5018_13  2020_01
# 953427  L15-1848E-0793N_7394_5018_13  2020_01
# 953428  L15-1848E-0793N_7394_5018_13  2020_01
# 953429  L15-1848E-0793N_7394_5018_13  2020_01
# 953430  L15-1848E-0793N_7394_5018_13  2020_01
#
# [953431 rows x 4 columns]

# %%
pred = pd.read_csv('/Midgard/home/hfang/temporal_CD/HRNet_SN7_csv/submission_hrnet_finetune4.csv')
aois = [z.split('mosaic_')[-1] for z in pred['filename'].values]
pred['aoi'] = aois
timesteps = [z.split('monthly_')[-1].split('_mosaic')[0] for z in pred['filename'].values]
pred['timestep'] = timesteps
pred = pred.drop('filename', 1)

# %%
pred.head()
# Out:
#    id                                           geometry  \
# 0   0  POLYGON (( 2.7 37.3,2.7 38,2.3 38,2.3 40.7,2.7...
# 1   0  POLYGON (( 2.7 37.3,2.7 38,2.3 38,2.3 40.7,2.7...
# 2   0  POLYGON (( 2.7 37.3,2.7 38,2.3 38,2.3 40.7,2.7...
# 3   0  POLYGON (( 2.7 37.3,2.7 38,2.3 38,2.3 40.7,2.7...
# 4   0  POLYGON (( 2.7 37.3,2.7 38,2.3 38,2.3 40.7,2.7...
#
#                             aoi timestep
# 0  L15-0632E-0892N_2528_4620_13  2018_01
# 1  L15-0632E-0892N_2528_4620_13  2018_02
# 2  L15-0632E-0892N_2528_4620_13  2018_03
# 3  L15-0632E-0892N_2528_4620_13  2018_04
# 4  L15-0632E-0892N_2528_4620_13  2018_05

# %%
pred['geometry'] = pred['geometry'].apply(wkt.loads)
pdf = gpd.GeoDataFrame(pred, geometry = 'geometry')
print(pdf)
# Out:
#           id                                           geometry  \
# 0          0  POLYGON ((2.700 37.300, 2.700 38.000, 2.300 38...
# 1          0  POLYGON ((2.700 37.300, 2.700 38.000, 2.300 38...
# 2          0  POLYGON ((2.700 37.300, 2.700 38.000, 2.300 38...
# 3          0  POLYGON ((2.700 37.300, 2.700 38.000, 2.300 38...
# 4          0  POLYGON ((2.700 37.300, 2.700 38.000, 2.300 38...
# ...      ...                                                ...
# 684040  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 684041  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 684042  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 684043  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
# 684044  2361  POLYGON ((924.300 1022.000, 924.300 1022.300, ...
#
#                                  aoi timestep
# 0       L15-0632E-0892N_2528_4620_13  2018_01
# 1       L15-0632E-0892N_2528_4620_13  2018_02
# 2       L15-0632E-0892N_2528_4620_13  2018_03
# 3       L15-0632E-0892N_2528_4620_13  2018_04
# 4       L15-0632E-0892N_2528_4620_13  2018_05
# ...                              ...      ...
# 684040  L15-1690E-1211N_6763_3346_13  2019_05
# 684041  L15-1690E-1211N_6763_3346_13  2019_06
# 684042  L15-1690E-1211N_6763_3346_13  2019_07
# 684043  L15-1690E-1211N_6763_3346_13  2019_08
# 684044  L15-1690E-1211N_6763_3346_13  2019_09
#
# [684045 rows x 4 columns]

# %%
scot.scot_multi_aoi(gdf, pdf, verbose=True)
# Out:
# 1 / 10: AOI L15-0387E-1276N_1549_3087_13
# Matching footprints
#    1: F1 = 0.4415
#    2: F1 = 0.4615
#    3: F1 = 0.4674
#    4: F1 = 0.4696
#    5: F1 = 0.4659
#    6: F1 = 0.4661
#    7: F1 = 0.4651
#    8: F1 = 0.4670
#    9: F1 = 0.4675
#   10: F1 = 0.4682
#   11: F1 = 0.4584
#   12: F1 = 0.4532
#   13: F1 = 0.4674
#   14: F1 = 0.4685
#   15: F1 = 0.4674
#   16: F1 = 0.4664
#   17: F1 = 0.4666
#   18: F1 = 0.4672
#   19: F1 = 0.4671
#   20: F1 = 0.4578
#   21: F1 = 0.4534
#   22: F1 = 0.4416
# Identifying mismatches
# Tracking:
#     Mismatches: 3
#       True Pos: 14136
#      False Pos: 9881
#      False Neg: 22949
#    Track Score: 0.4627
# Change Detection:
#       True Pos: 151
#      False Pos: 460
#      False Neg: 356
#   Change Score: 0.2701
# Combined Score: 0.4050
#
# 2 / 10: AOI L15-0566E-1185N_2265_3451_13
# Matching footprints
#    1: F1 = 0.2418
#    2: F1 = 0.2083
#    3: F1 = 0.2020
#    4: F1 = 0.1887
#    5: F1 = 0.2364
#    6: F1 = 0.2393
#    7: F1 = 0.2419
#    8: F1 = 0.2599
#    9: F1 = 0.2903
#   10: F1 = 0.4702
#   11: F1 = 0.4928
#   12: F1 = 0.5056
#   13: F1 = 0.5865
#   14: F1 = 0.5691
#   15: F1 = 0.5487
#   16: F1 = 0.5519
#   17: F1 = 0.6108
#   18: F1 = 0.6097
#   19: F1 = 0.6085
#   20: F1 = 0.5983
#   21: F1 = 0.5935
# Identifying mismatches
# Tracking:
#     Mismatches: 4
#       True Pos: 2738
#      False Pos: 2189
#      False Neg: 2451
#    Track Score: 0.5413
# Change Detection:
#       True Pos: 135
#      False Pos: 367
#      False Neg: 524
#   Change Score: 0.2326
# Combined Score: 0.4277
#
# 3 / 10: AOI L15-0632E-0892N_2528_4620_13
# Matching footprints
#    1: F1 = 0.4140
#    2: F1 = 0.4133
#    3: F1 = 0.4143
#    4: F1 = 0.4131
#    5: F1 = 0.4128
#    6: F1 = 0.4126
#    7: F1 = 0.4135
#    8: F1 = 0.4143
#    9: F1 = 0.4158
#   10: F1 = 0.4152
#   11: F1 = 0.4156
#   12: F1 = 0.4159
#   13: F1 = 0.4177
#   14: F1 = 0.4193
#   15: F1 = 0.4198
#   16: F1 = 0.4208
#   17: F1 = 0.4207
#   18: F1 = 0.4210
#   19: F1 = 0.4209
#   20: F1 = 0.4212
#   21: F1 = 0.4221
#   22: F1 = 0.4213
#   23: F1 = 0.4215
#   24: F1 = 0.4199
#   25: F1 = 0.4183
# Identifying mismatches
# Tracking:
#     Mismatches: 1
#       True Pos: 25738
#      False Pos: 33733
#      False Neg: 38102
#    Track Score: 0.4174
# Change Detection:
#       True Pos: 35
#      False Pos: 301
#      False Neg: 98
#   Change Score: 0.1493
# Combined Score: 0.3071
#
# 4 / 10: AOI L15-1015E-1062N_4061_3941_13
# Matching footprints
#    1: F1 = 0.6186
#    2: F1 = 0.6208
#    3: F1 = 0.6222
#    4: F1 = 0.6236
#    5: F1 = 0.6147
#    6: F1 = 0.6167
#    7: F1 = 0.6216
#    8: F1 = 0.6172
#    9: F1 = 0.6061
#   10: F1 = 0.6116
#   11: F1 = 0.6107
#   12: F1 = 0.6091
#   13: F1 = 0.6038
#   14: F1 = 0.6003
#   15: F1 = 0.6061
#   16: F1 = 0.5981
#   17: F1 = 0.5957
#   18: F1 = 0.5934
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 33999
#      False Pos: 20718
#      False Neg: 22831
#    Track Score: 0.6096
# Change Detection:
#       True Pos: 149
#      False Pos: 1023
#      False Neg: 529
#   Change Score: 0.1611
# Combined Score: 0.3915
#
# 5 / 10: AOI L15-1200E-0847N_4802_4803_13
# Matching footprints
#    1: F1 = 0.4718
#    2: F1 = 0.4719
#    3: F1 = 0.4723
#    4: F1 = 0.4897
#    5: F1 = 0.4727
#    6: F1 = 0.4730
#    7: F1 = 0.4730
#    8: F1 = 0.4732
#    9: F1 = 0.4733
#   10: F1 = 0.4733
#   11: F1 = 0.4734
#   12: F1 = 0.4737
#   13: F1 = 0.4737
#   14: F1 = 0.4737
#   15: F1 = 0.4741
#   16: F1 = 0.4740
#   17: F1 = 0.4743
#   18: F1 = 0.4744
#   19: F1 = 0.4750
#   20: F1 = 0.4757
#   21: F1 = 0.4755
#   22: F1 = 0.4751
#   23: F1 = 0.4757
#   24: F1 = 0.4752
# Identifying mismatches
# Tracking:
#     Mismatches: 6
#       True Pos: 103206
#      False Pos: 65569
#      False Neg: 163108
#    Track Score: 0.4744
# Change Detection:
#       True Pos: 28
#      False Pos: 223
#      False Neg: 162
#   Change Score: 0.1270
# Combined Score: 0.3066
#
# 6 / 10: AOI L15-1276E-1107N_5105_3761_13
# Matching footprints
#    1: F1 = 0.5233
#    2: F1 = 0.5227
#    3: F1 = 0.5235
#    4: F1 = 0.5231
#    5: F1 = 0.5230
#    6: F1 = 0.5222
#    7: F1 = 0.5221
#    8: F1 = 0.5197
#    9: F1 = 0.5197
#   10: F1 = 0.5240
#   11: F1 = 0.5256
#   12: F1 = 0.5241
#   13: F1 = 0.5217
#   14: F1 = 0.5228
#   15: F1 = 0.5217
#   16: F1 = 0.5209
#   17: F1 = 0.5217
#   18: F1 = 0.5220
#   19: F1 = 0.5212
#   20: F1 = 0.5244
#   21: F1 = 0.5245
#   22: F1 = 0.5233
#   23: F1 = 0.5195
#   24: F1 = 0.5159
#   25: F1 = 0.5130
# Identifying mismatches
# Tracking:
#     Mismatches: 2
#       True Pos: 32006
#      False Pos: 17548
#      False Neg: 41144
#    Track Score: 0.5217
# Change Detection:
#       True Pos: 76
#      False Pos: 704
#      False Neg: 641
#   Change Score: 0.1015
# Combined Score: 0.2854
#
# 7 / 10: AOI L15-1438E-1134N_5753_3655_13
# Matching footprints
#    1: F1 = 0.4774
#    2: F1 = 0.4777
#    3: F1 = 0.4782
#    4: F1 = 0.4783
#    5: F1 = 0.4783
#    6: F1 = 0.4550
#    7: F1 = 0.4820
#    8: F1 = 0.4785
#    9: F1 = 0.4795
#   10: F1 = 0.4793
#   11: F1 = 0.4796
#   12: F1 = 0.4793
#   13: F1 = 0.4792
#   14: F1 = 0.4789
#   15: F1 = 0.4782
#   16: F1 = 0.4782
#   17: F1 = 0.4751
#   18: F1 = 0.4584
#   19: F1 = 0.4775
#   20: F1 = 0.4773
#   21: F1 = 0.4770
#   22: F1 = 0.4769
# Identifying mismatches
# Tracking:
#     Mismatches: 26
#       True Pos: 120715
#      False Pos: 77587
#      False Neg: 187125
#    Track Score: 0.4770
# Change Detection:
#       True Pos: 2
#      False Pos: 768
#      False Neg: 316
#   Change Score: 0.0037
# Combined Score: 0.0178
#
# 8 / 10: AOI L15-1615E-1206N_6460_3366_13
# Matching footprints
#    1: F1 = 0.5895
#    2: F1 = 0.5905
#    3: F1 = 0.5905
#    4: F1 = 0.6172
#    5: F1 = 0.5922
#    6: F1 = 0.5920
#    7: F1 = 0.5926
#    8: F1 = 0.6032
#    9: F1 = 0.6041
#   10: F1 = 0.6097
#   11: F1 = 0.6104
#   12: F1 = 0.6107
#   13: F1 = 0.6097
#   14: F1 = 0.6005
#   15: F1 = 0.6088
#   16: F1 = 0.5769
#   17: F1 = 0.6082
#   18: F1 = 0.6091
#   19: F1 = 0.6083
#   20: F1 = 0.6076
#   21: F1 = 0.6060
#   22: F1 = 0.6049
#   23: F1 = 0.6041
#   24: F1 = 0.6066
#   25: F1 = 0.5995
#   26: F1 = 0.5889
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 47474
#      False Pos: 27383
#      False Neg: 35463
#    Track Score: 0.6017
# Change Detection:
#       True Pos: 39
#      False Pos: 417
#      False Neg: 199
#   Change Score: 0.1124
# Combined Score: 0.3216
#
# 9 / 10: AOI L15-1690E-1211N_6763_3346_13
# Matching footprints
#    1: F1 = 0.6182
#    2: F1 = 0.6168
#    3: F1 = 0.6164
#    4: F1 = 0.6171
#    5: F1 = 0.6184
#    6: F1 = 0.6171
#    7: F1 = 0.6174
#    8: F1 = 0.6173
#    9: F1 = 0.6139
#   10: F1 = 0.6148
#   11: F1 = 0.6140
#   12: F1 = 0.6153
#   13: F1 = 0.6116
#   14: F1 = 0.6030
#   15: F1 = 0.5880
#   16: F1 = 0.5759
#   17: F1 = 0.5916
#   18: F1 = 0.5923
#   19: F1 = 0.5933
#   20: F1 = 0.5900
#   21: F1 = 0.5809
#   22: F1 = 0.5804
#   23: F1 = 0.5768
#   24: F1 = 0.5693
# Identifying mismatches
# Tracking:
#     Mismatches: 9
#       True Pos: 26419
#      False Pos: 13707
#      False Neg: 21216
#    Track Score: 0.6021
# Change Detection:
#       True Pos: 48
#      False Pos: 274
#      False Neg: 456
#   Change Score: 0.1162
# Combined Score: 0.3279
#
# 10 / 10: AOI L15-1848E-0793N_7394_5018_13
# Matching footprints
#    1: F1 = 0.5162
#    2: F1 = 0.5218
#    3: F1 = 0.4683
#    4: F1 = 0.4717
#    5: F1 = 0.4430
#    6: F1 = 0.4717
#    7: F1 = 0.4711
#    8: F1 = 0.4690
#    9: F1 = 0.7059
#   10: F1 = 0.7213
#   11: F1 = 0.4247
#   12: F1 = 0.4281
#   13: F1 = 0.4625
#   14: F1 = 0.4611
# Identifying mismatches
# Tracking:
#     Mismatches: 7
#       True Pos: 5128
#      False Pos: 4171
#      False Neg: 7483
#    Track Score: 0.4681
# Change Detection:
#       True Pos: 173
#      False Pos: 418
#      False Neg: 710
#   Change Score: 0.2347
# Combined Score: 0.3905
# Overall score: 0.318127
# (0.3181265804323047,
#  {'L15-0387E-1276N_1549_3087_13': [3,
#    14136,
#    9881,
#    22949,
#    0.4627017118915911,
#    151,
#    460,
#    356,
#    0.2701252236135957,
#    0.4049610947944718],
#   'L15-0566E-1185N_2265_3451_13': [4,
#    2738,
#    2189,
#    2451,
#    0.5413206801107157,
#    135,
#    367,
#    524,
#    0.23255813953488372,
#    0.42774031882119884],
#   'L15-0632E-0892N_2528_4620_13': [1,
#    25738,
#    33733,
#    38102,
#    0.4174485650104208,
#    35,
#    301,
#    98,
#    0.14925373134328357,
#    0.3070872267081175],
#   'L15-1015E-1062N_4061_3941_13': [7,
#    33999,
#    20718,
#    22831,
#    0.6095905761696864,
#    149,
#    1023,
#    529,
#    0.16108108108108107,
#    0.3915477397531779],
#   'L15-1200E-0847N_4802_4803_13': [6,
#    103206,
#    65569,
#    163108,
#    0.47441328096090685,
#    28,
#    223,
#    162,
#    0.12698412698412698,
#    0.306626809479506],
#   'L15-1276E-1107N_5105_3761_13': [2,
#    32006,
#    17548,
#    41144,
#    0.5216781849002478,
#    76,
#    704,
#    641,
#    0.10153640614562458,
#    0.28544928206182674],
#   'L15-1438E-1134N_5753_3655_13': [26,
#    120715,
#    77587,
#    187125,
#    0.47700052554421485,
#    2,
#    768,
#    316,
#    0.003676470588235294,
#    0.017832576254557156],
#   'L15-1615E-1206N_6460_3366_13': [7,
#    47474,
#    27383,
#    35463,
#    0.6017212314790169,
#    39,
#    417,
#    199,
#    0.11239193083573487,
#    0.32164615979550687],
#   'L15-1690E-1211N_6763_3346_13': [9,
#    26419,
#    13707,
#    21216,
#    0.6020669773589635,
#    48,
#    274,
#    456,
#    0.1162227602905569,
#    0.3279130236325283],
#   'L15-1848E-0793N_7394_5018_13': [7,
#    5128,
#    4171,
#    7483,
#    0.4680967594705614,
#    173,
#    418,
#    710,
#    0.23473541383989144,
#    0.3904615730221556]})
